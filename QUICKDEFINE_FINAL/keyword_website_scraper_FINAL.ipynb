# %%
#required packages
import requests
from bs4 import BeautifulSoup
import pandas as pd
import pickle
import time
import urllib.parse 
import re

#reduces warnings output during requests without verification
requests.packages.urllib3.disable_warnings()
requests.packages.urllib3.util.ssl_.DEFAULT_CIPHERS += 'HIGH:!DH:!aNULL'
try:
    requests.packages.urllib3.contrib.pyopenssl.DEFAULT_SSL_CIPHER_LIST += 'HIGH:!DH:!aNULL'
except AttributeError:
    pass

# %%
#clean original concept keyword CSV file into array

df_orig = pd.read_csv("dataframe.csv")
df_clean = []

for i in df_orig["Link"]:
    clean = urllib.parse.unquote(str(i))
    clean = clean.replace('wiki/','').replace('_',' ').lower()
    df_clean.append(clean)
    
    
df_clean = df_clean[0:300]
    
df_clean
# Out:
# ['undefined behavior',
#  'sql injection',
#  'iso 8601',
#  'same origin policy',
#  'singleton pattern',
#  'single responsibility principle',
#  'model–view–controller',
#  'database normalization',
#  'dependency injection',
#  'byte order mark',
#  'trie',
#  "don't repeat yourself",
#  'jsonp',
#  'java version history',
#  'utf-8',
#  'cross-origin resource sharing',
#  'observer pattern',
#  'base64',
#  'maintenance mode',
#  'android (operating system)',
#  'endianness',
#  'levenshtein distance',
#  'strategy pattern',
#  'factory method pattern',
#  'json',
#  'regular expression',
#  'liskov substitution principle',
#  'legacy system',
#  'representational state transfer',
#  'list of http status codes',
#  'w/api.php',
#  'unix time',
#  'visitor pattern',
#  'hash table',
#  'cross-site scripting',
#  'decorator pattern',
#  'post/redirect/get',
#  'short-circuit evaluation',
#  'cron',
#  'ascii',
#  'data uri scheme',
#  'floating point',
#  'coordinated universal time',
#  'resource acquisition is initialization',
#  "two's complement",
#  'fisher–yates shuffle',
#  'big o notation',
#  'same-origin policy',
#  'sieve of eratosthenes',
#  'percent-encoding',
#  'separation of concerns',
#  'breadth-first search',
#  'curiously recurring template pattern',
#  'object-relational mapping',
#  'unobtrusive javascript',
#  'basic access authentication',
#  'hypertext transfer protocol',
#  'ajax (programming)',
#  'command pattern',
#  'memoization',
#  "dijkstra's algorithm",
#  'ieee floating point',
#  'quicksort',
#  'depth-first search',
#  'prepared statement',
#  'ansi escape code',
#  'bitwise operation',
#  'cross-site request forgery',
#  'double-precision floating-point format',
#  'universally unique identifier',
#  'list of tz database time zones',
#  'builder pattern',
#  'comma-separated values',
#  'template method pattern',
#  'websocket',
#  'duck typing',
#  'binary search algorithm',
#  'law of demeter',
#  'x86 calling conventions',
#  'knapsack problem',
#  'newline',
#  'jdbc driver',
#  'a',
#  'modulo operation',
#  'comet (programming)',
#  'object-oriented programming',
#  'windows-1252',
#  'aspect-oriented programming',
#  'hsl and hsv',
#  'merge sort',
#  'immediately-invoked function expression',
#  'sorting algorithm',
#  'null object pattern',
#  'adapter pattern',
#  'dynamic programming',
#  'w/index.php',
#  'race condition',
#  'http cookie',
#  'halting problem',
#  'kiss principle',
#  'join (sql)',
#  'call stack',
#  'inversion of control',
#  "de morgan's laws",
#  '.net framework',
#  'solid (object-oriented design)',
#  'name mangling',
#  'list of xml and html character entity references',
#  'composition over inheritance',
#  'abstract factory pattern',
#  'md5',
#  'quadtree',
#  'composite pattern',
#  'list of http header fields',
#  'rotation matrix',
#  'immutable object',
#  'query string',
#  'return value optimization',
#  'acid',
#  'hash function',
#  'facade pattern',
#  'javascript',
#  'most vexing parse',
#  'tail call',
#  'cartesian product',
#  'don',
#  'haversine formula',
#  'linear congruential generator',
#  'transmission control protocol',
#  'nanosecond',
#  'data structure alignment',
#  'comma operator',
#  'abstract syntax tree',
#  'comet (programming)',
#  'iso/iec 8859-1',
#  'inter-process communication',
#  'subset sum problem',
#  'executable and linkable format',
#  'ajax (programming)',
#  'include guard',
#  'fluent interface',
#  'pbkdf2',
#  'linked list',
#  'open/closed principle',
#  'bubble sort',
#  'dependency inversion principle',
#  'tree traversal',
#  'utf-16',
#  'serialization',
#  'push technology',
#  'bloom filter',
#  'currying',
#  'topological sorting',
#  'application binary interface',
#  'solid (object-oriented design)',
#  'cryptographic hash function',
#  'first normal form',
#  'mime',
#  'data transfer object',
#  'java native interface',
#  'virtual memory',
#  'america/montreal',
#  'finite-state machine',
#  'test-driven development',
#  'flood fill',
#  'list of tz zones by name',
#  'c++11',
#  'disjoint-set data structure',
#  'state pattern',
#  'variable-length array',
#  'fragment identifier',
#  'chunked transfer encoding',
#  'join (sql)',
#  'transport layer security',
#  'single-precision floating-point format',
#  'xmlhttprequest',
#  'bmp file format',
#  'rainbow table',
#  'uniform resource locator',
#  'address space layout randomization',
#  'k-d tree',
#  'lexicographical order',
#  'php',
#  'selection algorithm',
#  'xpath',
#  'advanced encryption standard',
#  'functional programming',
#  'birthday problem',
#  'unicode',
#  'bcrypt',
#  'c preprocessor',
#  'fibonacci number',
#  'xml',
#  'globally unique identifier',
#  'document object model',
#  'africa/casablanca',
#  'microsoft visual studio',
#  'system call',
#  'binary search tree',
#  'shunting-yard algorithm',
#  'travelling salesman problem',
#  'quirks mode',
#  'insertion sort',
#  'nan',
#  'man-in-the-middle attack',
#  'radix sort',
#  'flyweight pattern',
#  'jpeg',
#  'knuth–morris–pratt algorithm',
#  'progressive enhancement',
#  'two',
#  'block cipher mode of operation',
#  'just-in-time compilation',
#  'shebang (unix)',
#  'entity-attribute-value model',
#  'buffer overflow',
#  'code smell',
#  'c++0x',
#  'nosql',
#  'continuous integration',
#  'counting sort',
#  'exponentiation by squaring',
#  'jquery',
#  'operators in c and c++',
#  'shebang (unix)',
#  'mersenne twister',
#  'sequence point',
#  'recursive descent parser',
#  'b-tree',
#  'interval tree',
#  'nested set model',
#  'memory leak',
#  'suffix tree',
#  'model view viewmodel',
#  'free software',
#  'mock object',
#  'one definition rule',
#  'language integrated query',
#  'sargable',
#  'create, read, update and delete',
#  'foreign key',
#  'longest common subsequence problem',
#  'circular buffer',
#  'entity–attribute–value model',
#  'principle of least astonishment',
#  'windows forms',
#  '?',
#  'double-checked locking',
#  'proxy pattern',
#  'tz database',
#  'double dispatch',
#  'schwartzian transform',
#  'ieee 754-2008',
#  'reverse polish notation',
#  'salt (cryptography)',
#  'chain-of-responsibility pattern',
#  'domain-driven design',
#  'variable shadowing',
#  'euclidean distance',
#  'binary heap',
#  'daylight saving time',
#  'encapsulation (object-oriented programming)',
#  'pigeonhole principle',
#  'segmentation fault',
#  'unit testing',
#  'content delivery network',
#  'security through obscurity',
#  'utc offset',
#  'c++11',
#  'hough transform',
#  'ieee 754',
#  'row-major order',
#  'r-tree',
#  'design patterns',
#  'osi model',
#  'ternary operation',
#  'directed acyclic graph',
#  'mapreduce',
#  'rounding',
#  'regular language',
#  'interface segregation principle',
#  'k-means clustering',
#  'permutation',
#  'string interning',
#  'block cipher modes of operation',
#  'boyer–moore string search algorithm',
#  'nan',
#  'single-page application',
#  'network address translation',
#  'object composition',
#  'soap',
#  'public-key cryptography',
#  'sha-1',
#  'virtual method table',
#  'common intermediate language',
#  'model-view-controller',
#  'calling convention',
#  'point in polygon',
#  'hexadecimal',
#  'polymorphism in object-oriented programming']

# %%
# with open("kw_clean.txt", "wb") as fp:   #Pickling
#     pickle.dump(df_clean, fp)

# %%
#request URL function; can handle various connection errors
connect_fail_cause = []
def extract_html(link):
    try:
        resp = requests.get(link, verify=False, timeout=15) #will fail after 15secs for efficiency
        soup = BeautifulSoup(resp.content, "html.parser")
        connect_fail_cause.append(0)
        return soup
#         return soup2
    except requests.ConnectionError:
        connect_fail_cause.append(1)
        return "CONNECT_FUBAR"
    except requests.Timeout:
        connect_fail_cause.append(2)
        return "CONNECT_FUBAR"
    except requests.TooManyRedirects:
        connect_fail_cause.append(3)
        return "CONNECT_FUBAR"

# %%
#extract text from website html

def html_to_text(html):
    
    final = ''
    
    if isinstance(html,str)==False:
        text = html.find_all(['p','li']) #extracted tag types


        for p in text:
            final += p.text

        final = final.replace('\n',' ').replace('\r',' ').replace('\t','') #remove useless newline etc chars
        final = re.sub(' +', ' ', final) #remove space greater than one char length
    
    return final

# %%
#exclude site objects empty / insufficient length

def not_empty(site_obj):
    if site_obj['soup'] == 'CONNECT_FUBAR':
        return False
    elif not site_obj['soup']:
        return False
    elif (len(site_obj['raw_text'])>=120) == False:
        return False
    else:
        return True

# %%
single_page_time = []
google_page_time = []

# %%
#drives previous functions to gather HTML/text of x pages for a given keyword into an array
def fetch_pages(query, pages_per_kw):
    print('\nnew_kw_query')
    start_time_google = time.time()
    keyword = query
    query = query.replace(' ', '+')
    URL = f"https://google.com/search?q={query}&num=24" #set number of results as num
    headers = {"user-agent" : "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:65.0) Gecko/20100101 Firefox/65.0"}
    resp = requests.get(URL, headers=headers) #headers ensure Google server consistently accepts requests
    google_page_time.append(time.time()-start_time_google)
    
    if resp.status_code == 200:
        final = []
        soup = BeautifulSoup(resp.content, "html.parser")
        print('new_kw_query_success')
        for g in soup.find_all('div', class_='rc'): #div.rc element contains search result URLs
            if not g == False and len(final)<pages_per_kw: #this condition ensures each keyword consistently contains x pages
                start_time_single = time.time()
                title = g.find('h3').text
                link = g.find('a')['href']
                print(link)
                soup2 = extract_html(link)
                print('finished_extracting')
                raw_text = html_to_text(soup2)
                item = { #site object
                    "kw": keyword,
                    "title": title,
                    "link": link,
                    "soup": soup2,
                    "raw_text": raw_text
                        }
                
                if not_empty(item):
                    final.append(item)
                single_page_time.append(time.time()-start_time_single)
                print('site_query_complete')
    
    return final

# %%
#execute fetch_pages() here
master = []
start = 0
stop = 30
count = 0
x = df_clean[start:stop]
for kw in x: #NOTE: master array is nested in two layers: keyword---> site
    master.append(fetch_pages(kw, 16)) #set number of kw here
    count+=1
    print(int((count/(stop-start))*100),'% complete') #prints % progress of scraping
# Out:
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Undefined_behavior
# finished_extracting
# site_query_complete
# https://en.cppreference.com/w/cpp/language/ub
# finished_extracting
# site_query_complete
# https://en.cppreference.com/w/c/language/behavior
# finished_extracting
# site_query_complete
# https://www.geeksforgeeks.org/undefined-behavior-c-cpp/
# finished_extracting
# site_query_complete
# https://raphlinus.github.io/programming/rust/2018/08/17/undefined-behavior.html
# finished_extracting
# site_query_complete
# https://wiki.c2.com/?UndefinedBehavior
# finished_extracting
# site_query_complete
# https://blog.llvm.org/posts/2011-05-13-what-every-c-programmer-should-know/
# finished_extracting
# site_query_complete
# https://blog.regehr.org/archives/213
# finished_extracting
# site_query_complete
# https://embeddedartistry.com/blog/2017/01/09/a-guide-to-undefined-behavior-in-c-and-c-part-1/
# finished_extracting
# site_query_complete
# https://gist.github.com/Earnestly/7c903f481ff9d29a3dd1
# finished_extracting
# site_query_complete
# https://stackoverflow.com/questions/367633/what-are-all-the-common-undefined-behaviours-that-a-c-programmer-should-know-a
# finished_extracting
# site_query_complete
# http://wg21.link/P1705
# finished_extracting
# site_query_complete
# https://wiki.sei.cmu.edu/confluence/display/c/CC.+Undefined+Behavior
# finished_extracting
# site_query_complete
# https://wiki.sei.cmu.edu/confluence/display/c/MSC15-C.+Do+not+depend+on+undefined+behavior
# finished_extracting
# site_query_complete
# https://riptutorial.com/c/topic/364/undefined-behavior
# finished_extracting
# site_query_complete
# https://softwareengineering.stackexchange.com/questions/398703/why-does-c-have-undefined-behaviour-ub-and-other-languages-like-c-or-java
# finished_extracting
# site_query_complete
# https://softwareengineering.stackexchange.com/questions/99692/philosophy-behind-undefined-behavior
# finished_extracting
# site_query_complete
# 3 % complete
#
# new_kw_query
# new_kw_query_success
# https://www.w3schools.com/sql/sql_injection.asp
# finished_extracting
# site_query_complete
# https://portswigger.net/web-security/sql-injection
# finished_extracting
# site_query_complete
# https://www.acunetix.com/websitesecurity/sql-injection/
# finished_extracting
# site_query_complete
# https://en.wikipedia.org/wiki/SQL_injection
# finished_extracting
# site_query_complete
# https://owasp.org/www-community/attacks/SQL_Injection
# finished_extracting
# site_query_complete
# https://www.imperva.com/learn/application-security/sql-injection-sqli/
# finished_extracting
# site_query_complete
# https://www.veracode.com/security/sql-injection
# finished_extracting
# site_query_complete
# https://www.netsparker.com/blog/web-security/sql-injection-vulnerability/
# finished_extracting
# site_query_complete
# https://www.hacksplaining.com/exercises/sql-injection
# finished_extracting
# site_query_complete
# https://security.berkeley.edu/education-awareness/best-practices-how-tos/system-application-security/how-protect-against-sql
# finished_extracting
# site_query_complete
# https://www.hacksplaining.com/prevention/sql-injection
# finished_extracting
# site_query_complete
# https://www.php.net/manual/en/security.database.sql-injection.php
# finished_extracting
# site_query_complete
# https://www.ptsecurity.com/ww-en/analytics/knowledge-base/how-to-prevent-sql-injection-attacks/
# finished_extracting
# site_query_complete
# https://www.guru99.com/learn-sql-injection-with-practical-example.html
# finished_extracting
# site_query_complete
# http://www.unixwiz.net/techtips/sql-injection.html
# finished_extracting
# site_query_complete
# https://www.trendmicro.com/vinfo/au/security/definition/sql-injection
# finished_extracting
# site_query_complete
# 6 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/ISO_8601
# finished_extracting
# site_query_complete
# https://www.iso.org/iso-8601-date-and-time-format.html
# finished_extracting
# site_query_complete
# https://www.w3.org/TR/NOTE-datetime
# finished_extracting
# site_query_complete
# https://www.w3.org/QA/Tips/iso-date
# finished_extracting
# site_query_complete
# https://www.ionos.com/digitalguide/websites/web-development/iso-8601/
# finished_extracting
# site_query_complete
# https://www.digi.com/resources/documentation/digidocs/90001437-13/reference/r_iso_8601_date_format.htm
# finished_extracting
# site_query_complete
# https://xkcd.com/1179/
# finished_extracting
# site_query_complete
# https://www.cryptosys.net/pki/manpki/pki_iso8601datetime.html
# finished_extracting
# site_query_complete
# https://www.cl.cam.ac.uk/~mgk25/iso-time.html
# finished_extracting
# site_query_complete
# https://developer.mozilla.org/en/docs/Web/JavaScript/Reference/Global_Objects/Date/toISOString
# finished_extracting
# site_query_complete
# https://whatis.techtarget.com/definition/ISO-date-format
# finished_extracting
# site_query_complete
# https://stackoverflow.com/questions/114983/given-a-datetime-object-how-do-i-get-an-iso-8601-date-in-string-format
# finished_extracting
# site_query_complete
# https://tools.ietf.org/html/rfc3339
# finished_extracting
# site_query_complete
# https://microformats.org/wiki/iso-8601
# finished_extracting
# site_query_complete
# http://support.sas.com/documentation/cdl/en/lrdict/64316/HTML/default/viewer.htm#a003169814.htm
# finished_extracting
# site_query_complete
# https://downloads.haskell.org/~ghc/latest/docs/html/libraries/time-1.9.3/Data-Time-Format-ISO8601.html
# finished_extracting
# site_query_complete
# https://docs.python.org/3/library/datetime.html
# finished_extracting
# site_query_complete
# 10 % complete
#
# new_kw_query
# new_kw_query_success
# https://developer.mozilla.org/en-US/docs/Web/Security/Same-origin_policy
# finished_extracting
# site_query_complete
# https://en.wikipedia.org/wiki/Same-origin_policy
# finished_extracting
# site_query_complete
# https://www.w3.org/Security/wiki/Same_Origin_Policy
# finished_extracting
# site_query_complete
# https://www.acunetix.com/blog/web-security-zone/what-is-same-origin-policy/
# finished_extracting
# site_query_complete
# https://portswigger.net/web-security/cors/same-origin-policy
# finished_extracting
# site_query_complete
# https://web.dev/same-origin-policy/
# finished_extracting
# site_query_complete
# https://www.netsparker.com/whitepaper-same-origin-policy/
# finished_extracting
# site_query_complete
# https://medium.com/swlh/hacking-the-same-origin-policy-f9f49ad592fc
# finished_extracting
# site_query_complete
# https://stackoverflow.com/questions/14667189/simple-example-for-why-same-origin-policy-is-needed
# finished_extracting
# site_query_complete
# https://searchsecurity.techtarget.com/definition/Same-Origin-Policy-SOP
# finished_extracting
# site_query_complete
# https://www.linkedin.com/learning/web-security-same-origin-policies/understanding-same-origin-policies
# finished_extracting
# site_query_complete
# https://cdn.ttgtmedia.com/rms/pdf/Web_application_security.pdf
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# finished_extracting
# site_query_complete
# https://docs.fedoraproject.org/en-US/Fedora_Security_Team/1/html/Secure_Ruby_Development_Guide/ch03s02s02.html
# finished_extracting
# site_query_complete
# https://www.usenix.org/conference/usenixsecurity17/technical-sessions/presentation/schwenk
# finished_extracting
# site_query_complete
# https://security.stackexchange.com/questions/8264/why-is-the-same-origin-policy-so-important
# finished_extracting
# site_query_complete
# http://aosabook.org/en/500L/the-same-origin-policy.html
# finished_extracting
# site_query_complete
# https://link.springer.com/chapter/10.1007/978-3-642-22137-8_11
# finished_extracting
# site_query_complete
# 13 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Singleton_pattern
# finished_extracting
# site_query_complete
# https://www.tutorialspoint.com/design_pattern/singleton_pattern.htm
# finished_extracting
# site_query_complete
# https://refactoring.guru/design-patterns/singleton
# finished_extracting
# site_query_complete
# https://sourcemaking.com/design_patterns/singleton
# finished_extracting
# site_query_complete
# https://www.geeksforgeeks.org/singleton-design-pattern/
# finished_extracting
# site_query_complete
# https://www.journaldev.com/1377/java-singleton-design-pattern-best-practices-examples
# finished_extracting
# site_query_complete
# https://csharpindepth.com/articles/singleton
# finished_extracting
# site_query_complete
# https://wiki.freepascal.org/Singleton_Pattern
# finished_extracting
# site_query_complete
# https://www.oodesign.com/singleton-pattern.html
# finished_extracting
# site_query_complete
# https://gameprogrammingpatterns.com/singleton.html
# finished_extracting
# site_query_complete
# https://www.infoworld.com/article/2073352/core-java-simply-singleton.html
# finished_extracting
# site_query_complete
# https://www.dofactory.com/net/singleton-design-pattern
# finished_extracting
# site_query_complete
# https://www.dofactory.com/javascript/design-patterns/singleton
# finished_extracting
# site_query_complete
# https://medium.com/@andreaspoyias/design-patterns-a-quick-guide-to-singleton-pattern-60732ed43956
# finished_extracting
# site_query_complete
# https://medium.com/better-programming/the-complete-guide-to-the-singleton-design-pattern-dd0e7a5a4dc
# finished_extracting
# site_query_complete
# https://www.javatpoint.com/singleton-design-pattern-in-java
# finished_extracting
# site_query_complete
# 16 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Single-responsibility_principle
# finished_extracting
# site_query_complete
# https://stackify.com/solid-design-principles/
# finished_extracting
# site_query_complete
# https://medium.com/@severinperez/writing-flexible-code-with-the-single-responsibility-principle-b71c4f3f883f
# finished_extracting
# site_query_complete
# https://hackernoon.com/you-dont-understand-the-single-responsibility-principle-abfdd005b137
# finished_extracting
# site_query_complete
# https://deviq.com/single-responsibility-principle/
# finished_extracting
# site_query_complete
# https://www.toptal.com/software/single-responsibility-principle
# finished_extracting
# site_query_complete
# https://www.baeldung.com/java-single-responsibility-principle
# finished_extracting
# site_query_complete
# https://reflectoring.io/single-responsibility-principle/
# finished_extracting
# site_query_complete
# https://codeburst.io/understanding-solid-principles-single-responsibility-b7c7ec0bf80
# finished_extracting
# site_query_complete
# https://picnet.com.au/blog/solid-principles-part-one/
# finished_extracting
# site_query_complete
# https://www.oodesign.com/single-responsibility-principle.html
# finished_extracting
# site_query_complete
# https://code.tutsplus.com/tutorials/solid-part-1-the-single-responsibility-principle--net-36074
# finished_extracting
# site_query_complete
# https://thevaluable.dev/single-responsibility-principle-revisited/
# finished_extracting
# site_query_complete
# https://levelup.gitconnected.com/single-responsibility-principle-a-beginners-note-cb1eaba1fecd
# finished_extracting
# site_query_complete
# https://stackoverflow.com/questions/10620022/what-is-an-example-of-the-single-responsibility-principle
# finished_extracting
# site_query_complete
# https://towardsdatascience.com/solid-programming-part-1-single-responsibility-principle-efca5e7c2a87
# finished_extracting
# site_query_complete
# 20 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Model%E2%80%93view%E2%80%93controller
# finished_extracting
# site_query_complete
# https://www.codecademy.com/articles/mvc
# finished_extracting
# site_query_complete
# https://blog.codinghorror.com/understanding-model-view-controller/
# finished_extracting
# site_query_complete
# https://www.tutorialspoint.com/mvc_framework/mvc_framework_introduction.htm
# finished_extracting
# site_query_complete
# https://www.tutorialspoint.com/design_pattern/mvc_pattern.htm
# finished_extracting
# site_query_complete
# https://www.visual-paradigm.com/guide/uml-unified-modeling-language/what-is-model-view-control-mvc/
# finished_extracting
# site_query_complete
# https://dotnet.microsoft.com/apps/aspnet/mvc
# finished_extracting
# site_query_complete
# https://developer.chrome.com/apps/app_frameworks
# finished_extracting
# site_query_complete
# https://www.guru99.com/mvc-tutorial.html
# finished_extracting
# site_query_complete
# https://www.tutorialsteacher.com/mvc/mvc-architecture
# finished_extracting
# site_query_complete
# https://techterms.com/definition/mvc
# finished_extracting
# site_query_complete
# https://cocoacasts.com/what-is-wrong-with-model-view-controller
# finished_extracting
# site_query_complete
# https://help.hcltechsw.com/commerce/9.1.0/developer/concepts/csdmvcdespat.html
# finished_extracting
# site_query_complete
# https://martinfowler.com/eaaCatalog/modelViewController.html
# finished_extracting
# site_query_complete
# https://www.infoq.com/articles/no-more-mvc-frameworks/
# finished_extracting
# site_query_complete
# https://www.geeksforgeeks.org/mvc-design-pattern/
# finished_extracting
# site_query_complete
# 23 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Database_normalization
# finished_extracting
# site_query_complete
# https://www.guru99.com/database-normalization.html
# finished_extracting
# site_query_complete
# https://www.studytonight.com/dbms/database-normalization.php
# finished_extracting
# site_query_complete
# https://www.essentialsql.com/get-ready-to-learn-sql-database-normalization-explained-in-simple-english/
# finished_extracting
# site_query_complete
# https://docs.microsoft.com/en-us/office/troubleshoot/access/database-normalization-description
# finished_extracting
# site_query_complete
# https://beginnersbook.com/2015/05/normalization-in-dbms/
# finished_extracting
# site_query_complete
# https://opentextbc.ca/dbdesign01/chapter/chapter-12-normalization/
# finished_extracting
# site_query_complete
# http://agiledata.org/essays/dataNormalization.html
# finished_extracting
# site_query_complete
# https://www.edureka.co/blog/normalization-in-sql/
# finished_extracting
# site_query_complete
# https://towardsdatascience.com/database-normalization-explained-53e60a494495
# finished_extracting
# site_query_complete
# https://www.tutorialspoint.com/dbms/database_normalization.htm
# finished_extracting
# site_query_complete
# https://www.javatpoint.com/dbms-normalization
# finished_extracting
# site_query_complete
# https://condor.depaul.edu/gandrus/240IT/accesspages/normalization3.htm
# finished_extracting
# site_query_complete
# https://blog.saleslayer.com/why-is-database-normalization-so-important
# finished_extracting
# site_query_complete
# https://www.geeksforgeeks.org/normal-forms-in-dbms/
# finished_extracting
# site_query_complete
# https://mariadb.com/kb/en/database-normalization-5th-normal-form-and-beyond/
# finished_extracting
# site_query_complete
# https://mariadb.com/kb/en/database-normalization/
# finished_extracting
# site_query_complete
# 26 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Dependency_injection
# finished_extracting
# site_query_complete
# https://www.freecodecamp.org/news/a-quick-intro-to-dependency-injection-what-it-is-and-when-to-use-it-7578c84fa88f/
# finished_extracting
# site_query_complete
# https://www.tutorialsteacher.com/ioc/dependency-injection
# finished_extracting
# site_query_complete
# https://stackoverflow.com/questions/130794/what-is-dependency-injection
# finished_extracting
# site_query_complete
# https://stackify.com/dependency-injection/
# finished_extracting
# site_query_complete
# https://docs.microsoft.com/en-us/aspnet/core/fundamentals/dependency-injection
# finished_extracting
# site_query_complete
# https://angular.io/guide/dependency-injection
# finished_extracting
# site_query_complete
# https://www.youtube.com/watch/IKD2-MAkXyQ
# finished_extracting
# site_query_complete
# https://martinfowler.com/articles/injection.html
# finished_extracting
# site_query_complete
# https://developer.android.com/training/dependency-injection
# finished_extracting
# site_query_complete
# https://www.vogella.com/tutorials/DependencyInjection/article.html
# finished_extracting
# site_query_complete
# https://auth0.com/blog/dependency-injection-in-dotnet-core/
# finished_extracting
# site_query_complete
# https://developer.android.com/training/dependency-injection/manual
# finished_extracting
# site_query_complete
# https://doc.sitecore.com/developers/93/sitecore-experience-manager/en/dependency-injection.html
# finished_extracting
# site_query_complete
# https://docs.angularjs.org/guide/di
# finished_extracting
# site_query_complete
# https://aurelia.io/docs/fundamentals/dependency-injection/
# finished_extracting
# site_query_complete
# https://www.baeldung.com/inversion-control-and-dependency-injection-in-spring
# finished_extracting
# site_query_complete
# https://searchapparchitecture.techtarget.com/definition/dependency-injection
# finished_extracting
# site_query_complete
# 30 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Byte_order_mark
# finished_extracting
# site_query_complete
# https://simple.wikipedia.org/wiki/Byte_order_mark
# finished_extracting
# site_query_complete
# https://www.w3.org/International/questions/qa-byte-order-mark
# finished_extracting
# site_query_complete
# https://www.ionos.com/digitalguide/websites/web-development/byte-order-mark/
# finished_extracting
# site_query_complete
# https://unicode.org/faq/utf_bom.html
# finished_extracting
# site_query_complete
# https://www.techopedia.com/definition/799/byte-order-mark-bom
# finished_extracting
# site_query_complete
# https://www.ibm.com/support/knowledgecenter/en/SSULQD_7.2.1/com.ibm.nz.dbu.doc/c_dbuser_byte_order_mark.html
# finished_extracting
# site_query_complete
# https://web.stanford.edu/~laurik/fsmbook/errata/BOM.html
# finished_extracting
# site_query_complete
# https://www.liquid-technologies.com/XML/ByteOrderMarker.aspx
# finished_extracting
# site_query_complete
# https://stackoverflow.com/questions/2223882/whats-the-difference-between-utf-8-and-utf-8-without-bom
# finished_extracting
# site_query_complete
# https://wiki.simplemachines.org/smf/How_do_I_get_rid_of_a_Byte_Order_Mark
# finished_extracting
# site_query_complete
# https://docs.actian.com/dataconnect/11.0/User/Byte_Order_Marks.htm
# finished_extracting
# site_query_complete
# https://docs.microsoft.com/en-us/windows/win32/intl/using-byte-order-marks
# finished_extracting
# site_query_complete
# https://docs.microsoft.com/en-us/globalization/encoding/byte-order-mark
# finished_extracting
# site_query_complete
# https://community.microfocus.com/t5/Content-Manager-User-Discussions/Byte-Order-Mark/td-p/941207
# finished_extracting
# site_query_complete
# https://www.cryptosys.net/pki/utf8bom.html
# finished_extracting
# site_query_complete
# https://docs.sdl.com/791187/311631/sdl-contenta-5-7/byte-order-marks-boms-
# finished_extracting
# site_query_complete
# https://querysurge.zendesk.com/hc/en-us/articles/212789026-Flat-Files-with-the-Byte-Order-Mark-BOM-
# finished_extracting
# site_query_complete
# https://docs.teradata.com/reader/SaXXQ7zNjPoJl_0UduIfyQ/ZxcmHxwoDB0HlsZUSlbQeg
# finished_extracting
# site_query_complete
# https://www.oxfordreference.com/viewbydoi/10.1093/oi/authority.20110803095539871
# finished_extracting
# site_query_complete
# https://www.tutorialspoint.com/Unicode-Byte-Order-Mark-BOM-character-in-HTML5-document
# finished_extracting
# site_query_complete
# 33 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Trie
# finished_extracting
# site_query_complete
# https://www.geeksforgeeks.org/trie-insert-and-search/
# finished_extracting
# site_query_complete
# https://medium.com/basecs/trying-to-understand-tries-3ec6bede0014
# finished_extracting
# site_query_complete
# https://www.toptal.com/java/the-trie-a-neglected-data-structure
# finished_extracting
# site_query_complete
# https://www.cs.bu.edu/teaching/c/tree/trie/
# finished_extracting
# site_query_complete
# https://brilliant.org/wiki/tries/
# finished_extracting
# site_query_complete
# https://www.hackerearth.com/practice/data-structures/advanced-data-structures/trie-keyword-tree/tutorial/
# finished_extracting
# site_query_complete
# https://www.interviewcake.com/concept/java/trie
# finished_extracting
# site_query_complete
# http://users.monash.edu/~lloyd/tildeAlgDS/Tree/Trie/
# finished_extracting
# site_query_complete
# https://www.cs.usfca.edu/~galles/visualization/Trie.html
# finished_extracting
# site_query_complete
# https://xlinux.nist.gov/dads/HTML/trie.html
# finished_extracting
# site_query_complete
# https://www.baeldung.com/trie-java
# finished_extracting
# site_query_complete
# https://www.journaldev.com/36507/trie-data-structure-in-c-plus-plus
# finished_extracting
# site_query_complete
# https://www.researchgate.net/publication/255630648_Trie
# finished_extracting
# site_query_complete
# https://stackoverflow.com/questions/62201721/how-to-estimate-the-size-of-a-trie
# finished_extracting
# site_query_complete
# https://www.topcoder.com/community/competitive-programming/tutorials/using-tries/
# finished_extracting
# site_query_complete
# https://towardsdatascience.com/implementing-a-trie-data-structure-in-python-in-less-than-100-lines-of-code-a877ea23c1a1
# finished_extracting
# site_query_complete
# 36 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Don%27t_repeat_yourself
# finished_extracting
# site_query_complete
# https://deviq.com/don-t-repeat-yourself/
# finished_extracting
# site_query_complete
# https://medium.com/code-thoughts/dont-repeat-yourself-caa413910753
# finished_extracting
# site_query_complete
# https://www.oreilly.com/library/view/97-things-every/9780596809515/ch30.html
# finished_extracting
# site_query_complete
# https://wiki.c2.com/?DontRepeatYourself
# finished_extracting
# site_query_complete
# https://thevaluable.dev/dry-principle-cost-benefit-example/
# finished_extracting
# site_query_complete
# https://spin.atomicobject.com/2020/02/18/sometimes-repeat-yourself/
# finished_extracting
# site_query_complete
# https://dzone.com/articles/software-design-principles-dry-and-kiss
# finished_extracting
# site_query_complete
# https://ifrcgo.org/cbs/Documentation/Architecture/dry.html
# finished_extracting
# site_query_complete
# https://dev.to/abdelkbirkhoui1/don-t-repeat-yourself-principle-dry-6g5
# finished_extracting
# site_query_complete
# http://principles-wiki.net/principles:don_t_repeat_yourself
# finished_extracting
# site_query_complete
# https://zapier.com/blog/dont-repeat-yourself/
# finished_extracting
# site_query_complete
# https://www.earthdatascience.org/courses/earth-analytics/automate-science-workflows/write-efficient-code-for-science-r/
# finished_extracting
# site_query_complete
# https://dev.to/wuz/stop-trying-to-be-so-dry-instead-write-everything-twice-wet-5g33
# finished_extracting
# site_query_complete
# http://www.productivity501.com/dont-repeat-yourself/32/
# finished_extracting
# site_query_complete
# http://www.ifsq.org/finding-spm-123-a.html
# finished_extracting
# site_query_complete
# https://sites.google.com/site/agileskillsprojectwiki/agile-skills-inventory/technical-excellence/simple-design/don-t-repeat-yourself
# finished_extracting
# site_query_complete
# 40 % complete
#
# new_kw_query
# new_kw_query_success
# https://www.w3schools.com/JS/js_json_jsonp.asp
# finished_extracting
# site_query_complete
# https://stackoverflow.com/questions/2067472/what-is-jsonp-and-why-was-it-created
# finished_extracting
# site_query_complete
# https://en.wikipedia.org/wiki/JSONP
# finished_extracting
# site_query_complete
# https://blog.logrocket.com/jsonp-demystified-what-it-is-and-why-it-exists/
# finished_extracting
# site_query_complete
# https://www.sitepoint.com/jsonp-examples/
# finished_extracting
# site_query_complete
# https://codecraft.tv/courses/angular/http/jsonp-with-observables/
# finished_extracting
# site_query_complete
# https://flaviocopes.com/jsonp/
# finished_extracting
# site_query_complete
# https://www.w3resource.com/JSON/JSONP.php
# finished_extracting
# site_query_complete
# https://javaee.github.io/jsonp/
# finished_extracting
# site_query_complete
# http://techxposer.com/2017/11/14/understanding-jsonp-security-issues/
# finished_extracting
# site_query_complete
# https://gist.github.com/3380256
# finished_extracting
# site_query_complete
# https://github.com/jaubourg/jquery-jsonp
# finished_extracting
# site_query_complete
# https://www.getfilecloud.com/blog/using-jsonp-for-cross-domain-requests/
# finished_extracting
# site_query_complete
# https://www.loginradius.com/engineering/blog/understanding-jsonp/
# finished_extracting
# site_query_complete
# https://dev.socrata.com/docs/cors-and-jsonp.html
# finished_extracting
# site_query_complete
# https://dojotoolkit.org/documentation/tutorials/1.6/jsonp/
# finished_extracting
# site_query_complete
# https://www.ionos.com/digitalguide/websites/web-development/jsonp/
# finished_extracting
# site_query_complete
# 43 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Java_version_history
# finished_extracting
# site_query_complete
# https://en.wikipedia.org/wiki/Java_(software_platform)
# finished_extracting
# site_query_complete
# https://www.codejava.net/java-se/java-se-versions-history
# finished_extracting
# site_query_complete
# https://www.javatpoint.com/java-versions
# finished_extracting
# site_query_complete
# https://www.oracle.com/java/technologies/javase/jdk-relnotes-index.html
# finished_extracting
# site_query_complete
# https://minecraft.gamepedia.com/Java_Edition_version_history
# finished_extracting
# site_query_complete
# https://www.whizlabs.com/blog/java-version-history/
# finished_extracting
# site_query_complete
# https://medium.com/@hrishiraskar/java-versions-wise-feature-history-2fba2c59305e
# finished_extracting
# site_query_complete
# https://dzone.com/articles/a-guide-to-java-versions-and-features
# finished_extracting
# site_query_complete
# https://www.javajee.com/blog/java-version-history
# finished_extracting
# site_query_complete
# https://minecraft.fandom.com/wiki/Java_Edition_Version_History
# finished_extracting
# site_query_complete
# https://minecraft.fandom.com/wiki/Updates
# finished_extracting
# site_query_complete
# https://docs.adobe.com/docs/en/spec/jsr170/javadocs/jcr-2.0/javax/jcr/version/VersionHistory.html
# finished_extracting
# site_query_complete
# https://jafingerhut.github.io/clojure-benchmarks-results/Clojure-version-history.html
# finished_extracting
# site_query_complete
# https://support.hpe.com/hpsc/doc/public/display?docId=emr_na-a00046062en_us&docLocale=en_US
# finished_extracting
# site_query_complete
# https://en.wikibooks.org/wiki/Java_Programming/History
# finished_extracting
# site_query_complete
# https://www.hellocodies.com/java-version-history/
# finished_extracting
# site_query_complete
# https://www.guardsquare.com/en/products/proguard/manual/versions
# finished_extracting
# site_query_complete
# 46 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/UTF-8
# finished_extracting
# site_query_complete
# https://www.w3schools.com/charsets/ref_html_utf8.asp
# finished_extracting
# site_query_complete
# https://www.w3.org/International/questions/qa-what-is-encoding
# finished_extracting
# site_query_complete
# https://www.utf8-chartable.de/
# finished_extracting
# site_query_complete
# https://www.smashingmagazine.com/2012/06/all-about-unicode-utf8-character-sets/
# finished_extracting
# site_query_complete
# https://blog.hubspot.com/website/what-is-utf-8
# finished_extracting
# site_query_complete
# http://www.fileformat.info/info/charset/utf-8/list.htm
# finished_extracting
# site_query_complete
# https://www.fileformat.info/info/unicode/utf8.htm
# finished_extracting
# site_query_complete
# https://unicode.org/faq/utf_bom.html
# finished_extracting
# site_query_complete
# http://www.ltg.ed.ac.uk/~richard/utf-8.html
# finished_extracting
# site_query_complete
# https://www.twilio.com/docs/glossary/what-utf-8
# finished_extracting
# site_query_complete
# https://docs.python.org/3/howto/unicode.html
# finished_extracting
# site_query_complete
# https://developer.mozilla.org/en-US/docs/Glossary/UTF-8
# finished_extracting
# site_query_complete
# https://tools.ietf.org/html/rfc3629
# finished_extracting
# site_query_complete
# https://stackoverflow.com/questions/2241348/what-is-unicode-utf-8-utf-16
# finished_extracting
# site_query_complete
# http://tutorials.jenkov.com/unicode/utf-8.html
# finished_extracting
# site_query_complete
# https://help.alchemer.com/help/encode-an-excel-file-to-utf-8-or-utf-16
# finished_extracting
# site_query_complete
# http://www.columbia.edu/~fdc/utf8/
# finished_extracting
# site_query_complete
# https://www.php.net/manual/en/function.utf8-encode.php
# finished_extracting
# site_query_complete
# 50 % complete
#
# new_kw_query
# new_kw_query_success
# https://developer.mozilla.org/en-US/docs/Web/HTTP/CORS
# finished_extracting
# site_query_complete
# https://en.wikipedia.org/wiki/Cross-origin_resource_sharing
# finished_extracting
# site_query_complete
# https://auth0.com/blog/cors-tutorial-a-guide-to-cross-origin-resource-sharing/
# finished_extracting
# site_query_complete
# https://www.codecademy.com/articles/what-is-cors
# finished_extracting
# site_query_complete
# https://web.dev/cross-origin-resource-sharing/
# finished_extracting
# site_query_complete
# https://portswigger.net/web-security/cors
# finished_extracting
# site_query_complete
# https://www.moesif.com/blog/technical/cors/Authoritative-Guide-to-CORS-Cross-Origin-Resource-Sharing-for-REST-APIs/
# finished_extracting
# site_query_complete
# https://www.w3.org/TR/2020/SPSD-cors-20200602/
# finished_extracting
# site_query_complete
# https://www.w3.org/wiki/CORS
# finished_extracting
# site_query_complete
# https://docs.aws.amazon.com/AmazonS3/latest/dev/cors.html
# finished_extracting
# site_query_complete
# https://enable-cors.org/
# finished_extracting
# site_query_complete
# https://securityboulevard.com/2020/08/cross-origin-resource-sharing-cors-and-the-access-control-allow-origin-header/
# finished_extracting
# site_query_complete
# https://owasp.org/www-community/attacks/CORS_OriginHeaderScrutiny
# finished_extracting
# site_query_complete
# https://spring.io/guides/gs/rest-service-cors/
# finished_extracting
# site_query_complete
# https://cloud.google.com/storage/docs/cross-origin
# finished_extracting
# site_query_complete
# https://learn.akamai.com/en-us/webhelp/api-gateway/api-gateway-user-guide/GUID-FC33AE38-EE5B-444E-8ED5-AA48A5E02E3C.html
# finished_extracting
# site_query_complete
# https://developers.cloudflare.com/access/setting-up-access/cors
# finished_extracting
# site_query_complete
# 53 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Observer_pattern
# finished_extracting
# site_query_complete
# https://www.tutorialspoint.com/design_pattern/observer_pattern.htm
# finished_extracting
# site_query_complete
# https://refactoring.guru/design-patterns/observer
# finished_extracting
# site_query_complete
# https://sourcemaking.com/design_patterns/observer
# finished_extracting
# site_query_complete
# https://www.geeksforgeeks.org/observer-pattern-set-1-introduction/
# finished_extracting
# site_query_complete
# https://medium.com/datadriveninvestor/design-patterns-a-quick-guide-to-observer-pattern-d0622145d6c2
# finished_extracting
# site_query_complete
# https://medium.com/design-patterns-in-python/observer-pattern-c58820ad3c9f
# finished_extracting
# site_query_complete
# https://www.baeldung.com/java-observer-pattern
# finished_extracting
# site_query_complete
# https://www.sciencedirect.com/topics/computer-science/observer-pattern
# finished_extracting
# site_query_complete
# http://jargon.js.org/_glossary/OBSERVER_PATTERN.md
# finished_extracting
# site_query_complete
# https://www.dofactory.com/net/observer-design-pattern
# finished_extracting
# site_query_complete
# https://www.dofactory.com/javascript/design-patterns/observer
# finished_extracting
# site_query_complete
# https://gameprogrammingpatterns.com/observer.html
# finished_extracting
# site_query_complete
# https://www.oodesign.com/observer-pattern.html
# finished_extracting
# site_query_complete
# https://www.infoworld.com/article/2073299/an-inside-view-of-observer.html
# finished_extracting
# site_query_complete
# https://www.vogella.com/tutorials/DesignPatternObserver/article.html
# finished_extracting
# site_query_complete
# 56 % complete
#
# new_kw_query
# new_kw_query_success
# https://www.base64decode.org/
# finished_extracting
# site_query_complete
# https://en.wikipedia.org/wiki/Base64
# finished_extracting
# site_query_complete
# https://www.base64decode.net/
# finished_extracting
# site_query_complete
# https://developer.mozilla.org/en-US/docs/Glossary/Base64
# finished_extracting
# site_query_complete
# https://docs.python.org/3/library/base64.html
# finished_extracting
# site_query_complete
# https://tools.ietf.org/html/rfc4648
# finished_extracting
# site_query_complete
# https://www.base64-image.de/
# finished_extracting
# site_query_complete
# https://golang.org/pkg/encoding/base64/
# finished_extracting
# site_query_complete
# https://cryptii.com/pipes/base64-to-text
# finished_extracting
# site_query_complete
# https://www.freeformatter.com/base64-encoder.html
# finished_extracting
# site_query_complete
# https://ruby-doc.org/stdlib-2.5.3/libdoc/base64/rdoc/Base64.html
# finished_extracting
# site_query_complete
# https://docs.oracle.com/javase/8/docs/api/java/util/Base64.html
# finished_extracting
# site_query_complete
# https://docs.julialang.org/en/v1/stdlib/Base64/
# finished_extracting
# site_query_complete
# https://www.php.net/manual/en/function.base64-encode.php
# finished_extracting
# site_query_complete
# http://erlang.org/doc//man/base64.html
# finished_extracting
# site_query_complete
# https://base64.guru/converter/encode/image
# finished_extracting
# site_query_complete
# https://base64.guru/tools/validator
# finished_extracting
# site_query_complete
# https://www.url-encode-decode.com/base64-encode-decode/
# finished_extracting
# site_query_complete
# 60 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Maintenance_mode
# finished_extracting
# site_query_complete
# https://wordpress.org/plugins/wp-maintenance-mode/
# finished_extracting
# site_query_complete
# https://www.wpbeginner.com/plugins/how-to-put-your-wordpress-site-in-maintenance-mode/
# finished_extracting
# site_query_complete
# https://themeisle.com/blog/wordpress-maintenance-mode/
# finished_extracting
# site_query_complete
# https://docs.moodle.org/en/Maintenance_mode
# finished_extracting
# site_query_complete
# https://docs.microsoft.com/en-us/dynamics365/fin-ops-core/dev-itpro/sysadmin/maintenance-mode
# finished_extracting
# site_query_complete
# https://docs.microsoft.com/en-us/system-center/scom/manage-maintenance-mode-overview
# finished_extracting
# site_query_complete
# https://premium.wpmudev.org/blog/maintenance-mode/
# finished_extracting
# site_query_complete
# https://qodeinteractive.com/magazine/enable-wordpress-maintenance-mode/
# finished_extracting
# site_query_complete
# https://managewp.com/features/maintenance-mode
# finished_extracting
# site_query_complete
# https://devcenter.heroku.com/articles/maintenance-mode
# finished_extracting
# site_query_complete
# https://elementor.com/help/maintenance-mode/
# finished_extracting
# site_query_complete
# https://www.drupal.org/docs/user_guide/en/extend-maintenance.html
# finished_extracting
# site_query_complete
# https://octopus.com/docs/administration/managing-infrastructure/maintenance-mode
# finished_extracting
# site_query_complete
# https://support.helpspot.com/index.php?pg=kb.page&id=179
# finished_extracting
# site_query_complete
# https://www.my.versiondog.com/tl_files/versiondog_info/en/content/tutorials/commandline/commandline_103010.htm
# finished_extracting
# site_query_complete
# 63 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Android_(operating_system)
# finished_extracting
# site_query_complete
# https://www.computerworld.com/article/3235946/android-versions-a-living-history-from-1-0-to-today.html
# finished_extracting
# site_query_complete
# https://www.android.com/intl/en_au/
# finished_extracting
# site_query_complete
# https://www.samsung.com/au/support/mobile-devices/android-version-operating-system/
# finished_extracting
# site_query_complete
# https://www.investopedia.com/terms/a/android-operating-system.asp
# finished_extracting
# site_query_complete
# https://www.androidauthority.com/history-android-os-name-789433/
# finished_extracting
# site_query_complete
# https://www.dummies.com/consumer-electronics/smartphones/droid/looking-at-the-android-operating-system/
# finished_extracting
# site_query_complete
# https://www.verizon.com/support/android-os-faqs/
# finished_extracting
# site_query_complete
# https://www.howtogeek.com/345250/whats-the-latest-version-of-android/
# finished_extracting
# site_query_complete
# https://www.digitaltrends.com/mobile/android-version-history/
# finished_extracting
# site_query_complete
# https://www.finder.com.au/android-operating-system
# finished_extracting
# site_query_complete
# https://searchmobilecomputing.techtarget.com/definition/Android-OS
# finished_extracting
# site_query_complete
# https://familytime.io/kb/general/determining-android-os.html
# finished_extracting
# site_query_complete
# https://support.google.com/android/answer/7680439?hl=en
# finished_extracting
# site_query_complete
# https://download.cnet.com/utilities/android/
# finished_extracting
# site_query_complete
# https://gs.statcounter.com/os-market-share/mobile/worldwide
# finished_extracting
# site_query_complete
# https://www.tutorialspoint.com/android/android_overview.htm
# finished_extracting
# site_query_complete
# 66 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Endianness
# finished_extracting
# site_query_complete
# https://chortle.ccsu.edu/AssemblyTutorial/Chapter-15/ass15_3.html
# finished_extracting
# site_query_complete
# https://techterms.com/definition/endianness
# finished_extracting
# site_query_complete
# https://searchnetworking.techtarget.com/definition/big-endian-and-little-endian
# finished_extracting
# site_query_complete
# https://developer.mozilla.org/en-US/docs/Glossary/Endianness
# finished_extracting
# site_query_complete
# https://betterexplained.com/articles/understanding-big-and-little-endian-byte-order/
# finished_extracting
# site_query_complete
# https://www.section.io/engineering-education/what-is-little-endian-and-big-endian/
# finished_extracting
# site_query_complete
# https://www.geeksforgeeks.org/little-and-big-endian-mystery/
# finished_extracting
# site_query_complete
# https://www.embedded.com/introduction-to-endianness/
# finished_extracting
# site_query_complete
# https://www.embedded-computing.com/guest-blogs/endianness
# finished_extracting
# site_query_complete
# https://levelup.gitconnected.com/little-endian-vs-big-endian-eb2a2c3a9135
# finished_extracting
# site_query_complete
# https://study.com/academy/lesson/endianness-definition-formats-examples.html
# finished_extracting
# site_query_complete
# https://microchipdeveloper.com/32bit:mz-arch-isa-byte-ordering-endianness
# finished_extracting
# site_query_complete
# https://www.allaboutcircuits.com/technical-articles/big-endian-little-endian-endianness-byte-arrangement-digital-systems/
# finished_extracting
# site_query_complete
# https://sourceforge.net/p/predef/wiki/Endianness/
# finished_extracting
# site_query_complete
# https://www.ibm.com/support/knowledgecenter/en/SSEPEK_10.0.0/char/src/tpc/db2z_endianness.html
# finished_extracting
# site_query_complete
# https://superuser.com/questions/308274/what-determines-endianness/308333
# finished_extracting
# site_query_complete
# 70 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Levenshtein_distance
# finished_extracting
# site_query_complete
# https://dzone.com/articles/the-levenshtein-algorithm-1
# finished_extracting
# site_query_complete
# https://medium.com/@ethannam/understanding-the-levenshtein-distance-equation-for-beginners-c4285a5604f0
# finished_extracting
# site_query_complete
# https://people.cs.pitt.edu/~kirk/cs1501/Pruhs/Spring2006/assignments/editdistance/Levenshtein%20Distance.htm
# finished_extracting
# site_query_complete
# https://planetcalc.com/1721/
# finished_extracting
# site_query_complete
# https://www.educative.io/edpresso/the-levenshtein-distance-algorithm
# finished_extracting
# site_query_complete
# https://bmcbioinformatics.biomedcentral.com/articles/10.1186/s12859-019-2819-0
# finished_extracting
# site_query_complete
# https://blogs.mathworks.com/cleve/2017/08/14/levenshtein-edit-distance-between-strings/
# finished_extracting
# site_query_complete
# https://www.sciencedirect.com/topics/computer-science/levenshtein-distance
# finished_extracting
# site_query_complete
# https://www.baeldung.com/cs/levenshtein-distance-computation
# finished_extracting
# site_query_complete
# https://en.wikibooks.org/wiki/Algorithm_Implementation/Strings/Levenshtein_distance
# finished_extracting
# site_query_complete
# https://itnext.io/levenshtein-distance-in-typescript-6de81ea2fb63
# finished_extracting
# site_query_complete
# https://towardsdatascience.com/how-to-improve-the-performance-of-a-machine-learning-model-with-post-processing-employing-b8559d2d670a
# finished_extracting
# site_query_complete
# https://www.researchgate.net/publication/262088592_Improved_versions_of_the_Levenshtein_distance_method_for_comparing_sequence_information_in_animals%27_vocalisations_Tests_using_humpback_whale_song
# finished_extracting
# site_query_complete
# https://nlp.stanford.edu/IR-book/html/htmledition/edit-distance-1.html
# finished_extracting
# site_query_complete
# http://www.levenshtein.net/
# finished_extracting
# site_query_complete
# 73 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Strategy_pattern
# finished_extracting
# site_query_complete
# https://www.tutorialspoint.com/design_pattern/strategy_pattern.htm
# finished_extracting
# site_query_complete
# https://refactoring.guru/design-patterns/strategy
# finished_extracting
# site_query_complete
# https://sourcemaking.com/design_patterns/strategy
# finished_extracting
# site_query_complete
# https://www.geeksforgeeks.org/strategy-pattern-set-1/
# finished_extracting
# site_query_complete
# https://blog.bitsrc.io/keep-it-simple-with-the-strategy-design-pattern-c36a14c985e9
# finished_extracting
# site_query_complete
# https://www.dofactory.com/net/strategy-design-pattern
# finished_extracting
# site_query_complete
# https://www.youtube.com/watch/v9ejT8FO-7I
# finished_extracting
# site_query_complete
# https://www.oodesign.com/strategy-pattern.html
# finished_extracting
# site_query_complete
# https://codewithshadman.com/strategy-pattern-csharp/
# finished_extracting
# site_query_complete
# https://www.topcoder.com/thrive/articles/The%20Strategy%20Pattern%20in%20C
# finished_extracting
# site_query_complete
# https://medium.com/dev-genius/design-patterns-strategy-pattern-d57a13c593b7
# finished_extracting
# site_query_complete
# https://medium.com/fintechexplained/strategy-design-pattern-a1f643617d5c
# finished_extracting
# site_query_complete
# https://www.ionos.com/digitalguide/websites/web-development/strategy-pattern/
# finished_extracting
# site_query_complete
# https://wiki.c2.com/?StrategyPattern
# finished_extracting
# site_query_complete
# https://www.freecodecamp.org/news/the-strategy-pattern-explained-using-java-bc30542204e0/
# finished_extracting
# site_query_complete
# https://www.programmingwithwolfgang.com/strategy-pattern/
# finished_extracting
# site_query_complete
# https://deviq.com/strategy-design-pattern/
# finished_extracting
# site_query_complete
# 76 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Factory_method_pattern
# finished_extracting
# site_query_complete
# https://refactoring.guru/design-patterns/factory-method
# finished_extracting
# site_query_complete
# https://www.tutorialspoint.com/design_pattern/factory_pattern.htm
# finished_extracting
# site_query_complete
# https://sourcemaking.com/design_patterns/factory_method
# finished_extracting
# site_query_complete
# https://www.javatpoint.com/factory-method-design-pattern
# finished_extracting
# site_query_complete
# https://www.geeksforgeeks.org/design-patterns-set-2-factory-method/
# finished_extracting
# site_query_complete
# https://realpython.com/factory-method-python/
# finished_extracting
# site_query_complete
# https://www.dofactory.com/net/factory-method-design-pattern
# finished_extracting
# site_query_complete
# https://medium.com/@info.anikdey003/factory-method-design-pattern-277dd4bd3a11
# finished_extracting
# site_query_complete
# https://cs.anu.edu.au/courses/comp2500/notes/15factory.slides.pdf
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# finished_extracting
# site_query_complete
# https://www.baeldung.com/creational-design-patterns
# finished_extracting
# site_query_complete
# https://www.oreilly.com/library/view/head-first-design/0596007124/ch04.html
# finished_extracting
# site_query_complete
# https://dzone.com/articles/factory-method-design-pattern
# finished_extracting
# site_query_complete
# https://stackabuse.com/the-factory-method-design-pattern-in-python/
# finished_extracting
# site_query_complete
# https://stackabuse.com/factory-method-design-pattern-in-java/
# finished_extracting
# site_query_complete
# https://dart.academy/creational-design-patterns-for-dart-and-flutter-factory-method/
# finished_extracting
# site_query_complete
# https://narbase.com/2020/06/15/design-patterns-factory-method-with-kotlin-examples/
# finished_extracting
# site_query_complete
# 80 % complete
#
# new_kw_query
# new_kw_query_success
# https://www.json.org/
# finished_extracting
# site_query_complete
# https://en.wikipedia.org/wiki/JSON
# finished_extracting
# site_query_complete
# https://www.w3schools.com/whatis/whatis_json.asp
# finished_extracting
# site_query_complete
# https://www.w3schools.com/js/js_json_intro.asp
# finished_extracting
# site_query_complete
# https://developer.mozilla.org/en-US/docs/Learn/JavaScript/Objects/JSON
# finished_extracting
# site_query_complete
# https://developer.mozilla.org/en/docs/Web/JavaScript/Reference/Global_Objects/JSON
# finished_extracting
# site_query_complete
# https://www.copterlabs.com/json-what-it-is-how-it-works-how-to-use-it/
# finished_extracting
# site_query_complete
# http://jsonviewer.stack.hu/
# finished_extracting
# site_query_complete
# https://www.infoworld.com/article/3222851/what-is-json-a-better-format-for-data-exchange.html
# finished_extracting
# site_query_complete
# https://www.tutorialspoint.com/json/json_quick_guide.htm
# finished_extracting
# site_query_complete
# https://javaee.github.io/tutorial/jsonp001.html
# finished_extracting
# site_query_complete
# https://beginnersbook.com/2015/04/json-tutorial/
# finished_extracting
# site_query_complete
# https://json-schema.org/
# finished_extracting
# site_query_complete
# https://jsoneditoronline.org/
# finished_extracting
# site_query_complete
# https://tools.ietf.org/html/rfc7159
# finished_extracting
# site_query_complete
# https://developers.squarespace.com/what-is-json
# finished_extracting
# site_query_complete
# https://www.freeformatter.com/json-formatter.html
# finished_extracting
# site_query_complete
# https://jsonformatter.curiousconcept.com/
# finished_extracting
# site_query_complete
# https://jsonapi.org/
# finished_extracting
# site_query_complete
# https://docs.python.org/3/library/json.html
# finished_extracting
# site_query_complete
# https://www.safe.com/integrate/json/
# finished_extracting
# site_query_complete
# 83 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Regular_expression
# finished_extracting
# site_query_complete
# https://regexr.com/
# finished_extracting
# site_query_complete
# https://developer.mozilla.org/en/docs/Web/JavaScript/Guide/Regular_Expressions
# finished_extracting
# site_query_complete
# https://www.rexegg.com/regex-quickstart.html
# finished_extracting
# site_query_complete
# https://docs.python.org/3/howto/regex.html
# finished_extracting
# site_query_complete
# https://docs.python.org/3/library/re.html
# finished_extracting
# site_query_complete
# https://www.w3schools.com/jsref/jsref_obj_regexp.asp
# finished_extracting
# site_query_complete
# https://cran.r-project.org/web/packages/stringr/vignettes/regular-expressions.html
# finished_extracting
# site_query_complete
# https://www.mathworks.com/help/matlab/matlab_prog/regular-expressions.html
# finished_extracting
# site_query_complete
# https://www.regular-expressions.info/
# finished_extracting
# site_query_complete
# https://regex101.com/
# finished_extracting
# site_query_complete
# https://support.google.com/analytics/answer/1034324?hl=en
# finished_extracting
# site_query_complete
# https://regexone.com/
# finished_extracting
# site_query_complete
# https://eloquentjavascript.net/09_regexp.html
# finished_extracting
# site_query_complete
# https://www3.ntu.edu.sg/home/ehchua/programming/howto/Regexe.html
# finished_extracting
# site_query_complete
# https://www.vogella.com/tutorials/JavaRegularExpressions/article.html
# finished_extracting
# site_query_complete
# https://www.regular-expressions.info/quickstart.html
# finished_extracting
# site_query_complete
# https://www.gnu.org/software/sed/manual/html_node/Regular-Expressions.html
# finished_extracting
# site_query_complete
# 86 % complete
#
# new_kw_query
# new_kw_query_success
# https://stackify.com/solid-design-liskov-substitution-principle/
# finished_extracting
# site_query_complete
# https://en.wikipedia.org/wiki/Liskov_substitution_principle
# finished_extracting
# site_query_complete
# https://stackoverflow.com/questions/56860/what-is-an-example-of-the-liskov-substitution-principle
# finished_extracting
# site_query_complete
# https://reflectoring.io/lsp-explained/
# finished_extracting
# site_query_complete
# https://www.baeldung.com/java-liskov-substitution-principle
# finished_extracting
# site_query_complete
# https://www.baeldung.com/cs/liskov-substitution-principle
# finished_extracting
# site_query_complete
# https://www.tomdalling.com/blog/software-design/solid-class-design-the-liskov-substitution-principle/
# finished_extracting
# site_query_complete
# https://dev.to/erikwhiting88/liskov-substitution-principle-in-3-minutes-2dc6
# finished_extracting
# site_query_complete
# https://springframework.guru/principles-of-object-oriented-design/liskov-substitution-principle/
# finished_extracting
# site_query_complete
# https://medium.com/swlh/liskovs-substitution-principle-c39dd53910a9
# finished_extracting
# site_query_complete
# https://ducmanhphan.github.io/2020-01-13-Understanding-about-SOLID-part-3/
# finished_extracting
# site_query_complete
# https://dzone.com/articles/the-liskov-substitution-principle-with-examples
# finished_extracting
# site_query_complete
# https://www.oodesign.com/liskov-s-substitution-principle.html
# finished_extracting
# site_query_complete
# https://wiki.c2.com/?LiskovSubstitutionPrinciple
# finished_extracting
# site_query_complete
# https://php.watch/articles/php-lsp
# finished_extracting
# site_query_complete
# https://www.infoworld.com/article/2971271/exploring-the-liskov-substitution-principle.html
# finished_extracting
# site_query_complete
# https://www.linkedin.com/learning/learning-s-o-l-i-d-programming-principles/introduction-to-liskov-substitution
# finished_extracting
# site_query_complete
# 90 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Legacy_system
# finished_extracting
# site_query_complete
# https://www.talend.com/resources/what-is-legacy-system/
# finished_extracting
# site_query_complete
# https://www.altexsoft.com/whitepapers/legacy-system-modernization-how-to-transform-the-enterprise-for-digital-future/
# finished_extracting
# site_query_complete
# https://freeportmetrics.com/blog/what-is-a-legacy-system-and-why-do-companies-keep-using-them/
# finished_extracting
# site_query_complete
# https://randed.com/legacy-system/?lang=en
# finished_extracting
# site_query_complete
# https://www.techopedia.com/definition/635/legacy-system
# finished_extracting
# site_query_complete
# https://www.sciencedirect.com/topics/computer-science/legacy-systems
# finished_extracting
# site_query_complete
# https://blog.userlane.com/enterprise-legacy-systems/
# finished_extracting
# site_query_complete
# https://www.stromasys.com/2016/07/an-overview-of-legacy-software-and-legacy-systems/
# finished_extracting
# site_query_complete
# https://www.sebokwiki.org/wiki/Legacy_System_(glossary)
# finished_extracting
# site_query_complete
# https://www.yourdictionary.com/legacy-system
# finished_extracting
# site_query_complete
# https://www.bigcommerce.com.au/ecommerce-answers/what-legacy-system/
# finished_extracting
# site_query_complete
# https://www.youredi.com/blog/legacy-system-integration
# finished_extracting
# site_query_complete
# https://wiredelta.com/10-reasons-to-move-away-from-legacy-systems/
# finished_extracting
# site_query_complete
# https://www.goodcore.co.uk/blog/legacy-systems/
# finished_extracting
# site_query_complete
# https://www.mckennaconsultants.com/legacy-system-migration/
# finished_extracting
# site_query_complete
# https://www.itnews.com.au/news/sa-govt-spends-20m-plus-on-legacy-system-support-each-year-553032
# finished_extracting
# site_query_complete
# https://spectrum.ieee.org/computing/it/inside-hidden-world-legacy-it-systems
# finished_extracting
# site_query_complete
# https://blog.dreamfactory.com/what-is-a-legacy-system/
# finished_extracting
# site_query_complete
# 93 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/Representational_state_transfer
# finished_extracting
# site_query_complete
# https://www.codecademy.com/articles/what-is-rest
# finished_extracting
# site_query_complete
# https://medium.com/@sagar.mane006/understanding-rest-representational-state-transfer-85256b9424aa
# finished_extracting
# site_query_complete
# https://searchapparchitecture.techtarget.com/definition/REST-REpresentational-State-Transfer
# finished_extracting
# site_query_complete
# https://www.plesk.com/blog/various/rest-representational-state-transfer/
# finished_extracting
# site_query_complete
# https://www.ics.uci.edu/~fielding/pubs/dissertation/rest_arch_style.htm
# finished_extracting
# site_query_complete
# https://restfulapi.net/
# finished_extracting
# site_query_complete
# https://www.sciencedirect.com/topics/computer-science/representational-state-transfer
# finished_extracting
# site_query_complete
# https://apifriends.com/api-management/what-is-rest-api/
# finished_extracting
# site_query_complete
# https://www.mulesoft.com/resources/api/what-is-rest-api-design
# finished_extracting
# site_query_complete
# https://stackoverflow.com/questions/10418105/what-does-representational-state-mean-in-rest
# finished_extracting
# site_query_complete
# https://bmcmedinformdecismak.biomedcentral.com/articles/10.1186/1472-6947-13-57
# finished_extracting
# site_query_complete
# https://doubleoctopus.com/security-wiki/protocol/representational-state-transfer/
# finished_extracting
# site_query_complete
# https://www.netiq.com/documentation/operations-center-57/web2connect/data/bli2d6q.html
# finished_extracting
# site_query_complete
# https://www.service-architecture.com/articles/web-services/representational_state_transfer_rest.html
# finished_extracting
# site_query_complete
# https://docs.jboss.org/exojcr/1.12.13-GA/developer/en-US/html/ch-introduction-to-rest.html
# finished_extracting
# site_query_complete
# https://clouddocs.f5.com/training/community/firewall/html/archive/archive1/lab6/step2.html
# finished_extracting
# site_query_complete
# https://www.researchgate.net/publication/265062416_Evaluating_a_Representational_State_Transfer_REST_Architecture_What_is_the_Impact_of_REST_in_My_Architecture
# finished_extracting
# site_query_complete
# 96 % complete
#
# new_kw_query
# new_kw_query_success
# https://en.wikipedia.org/wiki/List_of_HTTP_status_codes
# finished_extracting
# site_query_complete
# https://developer.mozilla.org/en-US/docs/Web/HTTP/Status
# finished_extracting
# site_query_complete
# https://www.restapitutorial.com/httpstatuscodes.html
# finished_extracting
# site_query_complete
# https://httpstatuses.com/
# finished_extracting
# site_query_complete
# https://www.w3.org/Protocols/rfc2616/rfc2616-sec10.html
# finished_extracting
# site_query_complete
# https://www.w3.org/Protocols/HTTP/HTRESP.html
# finished_extracting
# site_query_complete
# https://www.iana.org/assignments/http-status-codes
# finished_extracting
# site_query_complete
# https://kinsta.com/blog/http-status-codes/
# finished_extracting
# site_query_complete
# https://www.tutorialspoint.com/http/http_status_codes.htm
# finished_extracting
# site_query_complete
# https://umbraco.com/about-us/umbraco-dictionary/http-status-codes/
# finished_extracting
# site_query_complete
# https://blog.hubspot.com/marketing/http-status-codes
# finished_extracting
# site_query_complete
# https://en.ryte.com/wiki/Http_Status_Code
# finished_extracting
# site_query_complete
# https://restfulapi.net/http-status-codes/
# finished_extracting
# site_query_complete
# https://developer.cdn.mozilla.net/th/docs/Web/HTTP/Status
# finished_extracting
# site_query_complete
# https://www.digitalocean.com/community/tutorials/how-to-troubleshoot-common-http-error-codes
# finished_extracting
# site_query_complete
# https://www.whoishostingthis.com/resources/http-status-codes/
# finished_extracting
# site_query_complete
# https://www.tutorialrepublic.com/html-reference/http-status-codes.php
# finished_extracting
# site_query_complete
# 100 % complete

# %%
result = []
result.append(connect_fail_cause)
result.append(single_page_time)
result.append(google_page_time)

# %%
# with open("runtime_50_100.txt", "wb") as fp:
#     pickle.dump(result, fp)

# %%
#Example
master[0][0]
# Out:
# {'kw': 'undefined behavior',
#  'title': 'Undefined behavior - Wikipedia',
#  'link': 'https://en.wikipedia.org/wiki/Undefined_behavior',
#  'soup': <!DOCTYPE html>
#
#  <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#  <meta charset="utf-8"/>
#  <title>Undefined behavior - Wikipedia</title>
#  <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"613436fa-e493-4345-b7cf-a2f1049997ea","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Undefined_behavior","wgTitle":"Undefined behavior","wgCurRevisionId":959672567,"wgRevisionId":959672567,"wgArticleId":515992,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["All articles with unsourced statements","Articles with unsourced statements from December 2019","Articles with example C++ code","Programming language implementation","C (programming language)","C++"],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":
#  "Undefined_behavior","wgRelevantArticleId":515992,"wgIsProbablyEditable":!0,"wgRelevantPageIsProbablyEditable":!0,"wgRestrictionEdit":[],"wgRestrictionMove":[],"wgMediaViewerOnClick":!0,"wgMediaViewerEnabledByDefault":!0,"wgPopupsReferencePreviews":!1,"wgPopupsConflictsWithNavPopupGadget":!1,"wgVisualEditor":{"pageLanguageCode":"en","pageLanguageDir":"ltr","pageVariantFallbacks":"en"},"wgMFDisplayWikibaseDescriptions":{"search":!0,"nearby":!0,"watchlist":!0,"tagline":!1},"wgWMESchemaEditAttemptStepOversample":!1,"wgULSCurrentAutonym":"English","wgNoticeProject":"wikipedia","wgCentralAuthMobileDomain":!1,"wgEditSubmitButtonLabelPublish":!0,"wgULSPosition":"interlanguage","wgWikibaseItemId":"Q1964707"};RLSTATE={"ext.globalCssJs.user.styles":"ready","site.styles":"ready","noscript":"ready","user.styles":"ready","ext.globalCssJs.user":"ready","user":"ready","user.options":"loading","ext.cite.styles":"ready","ext.pygments":"ready","skins.vector.styles.legacy":
#  "ready","mediawiki.toc.styles":"ready","ext.visualEditor.desktopArticleTarget.noscript":"ready","ext.uls.interlanguage":"ready","ext.wikimediaBadges":"ready","wikibase.client.init":"ready"};RLPAGEMODULES=["ext.cite.ux-enhancements","site","mediawiki.page.ready","mediawiki.toc","skins.vector.legacy.js","ext.gadget.ReferenceTooltips","ext.gadget.charinsert","ext.gadget.extra-toolbar-buttons","ext.gadget.refToolbar","ext.gadget.switcher","ext.centralauth.centralautologin","ext.popups","ext.visualEditor.desktopArticleTarget.init","ext.visualEditor.targetLoader","ext.eventLogging","ext.wikimediaEvents","ext.navigationTiming","ext.uls.compactlinks","ext.uls.interface","ext.cx.eventlogging.campaigns","ext.quicksurveys.init","ext.centralNotice.geoIP","ext.centralNotice.startUp"];</script>
#  <script>(RLQ=window.RLQ||[]).push(function(){mw.loader.implement("user.options@1hzgi",function($,jQuery,require,module){/*@nomin*/mw.user.tokens.set({"patrolToken":"+\\","watchToken":"+\\","csrfToken":"+\\"});
#  });});</script>
#  <link href="/w/load.php?lang=en&amp;modules=ext.cite.styles%7Cext.pygments%2CwikimediaBadges%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cmediawiki.toc.styles%7Cskins.vector.styles.legacy%7Cwikibase.client.init&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#  <script async="" src="/w/load.php?lang=en&amp;modules=startup&amp;only=scripts&amp;raw=1&amp;skin=vector"></script>
#  <meta content="" name="ResourceLoaderDynamicStyles"/>
#  <link href="/w/load.php?lang=en&amp;modules=site.styles&amp;only=styles&amp;skin=vector" rel="stylesheet"/>
#  <meta content="MediaWiki 1.36.0-wmf.14" name="generator"/>
#  <meta content="origin" name="referrer"/>
#  <meta content="origin-when-crossorigin" name="referrer"/>
#  <meta content="origin-when-cross-origin" name="referrer"/>
#  <link href="//en.m.wikipedia.org/wiki/Undefined_behavior" media="only screen and (max-width: 720px)" rel="alternate"/>
#  <link href="/w/index.php?title=Undefined_behavior&amp;action=edit" rel="alternate" title="Edit this page" type="application/x-wiki"/>
#  <link href="/w/index.php?title=Undefined_behavior&amp;action=edit" rel="edit" title="Edit this page"/>
#  <link href="/static/apple-touch/wikipedia.png" rel="apple-touch-icon"/>
#  <link href="/static/favicon/wikipedia.ico" rel="shortcut icon"/>
#  <link href="/w/opensearch_desc.php" rel="search" title="Wikipedia (en)" type="application/opensearchdescription+xml"/>
#  <link href="//en.wikipedia.org/w/api.php?action=rsd" rel="EditURI" type="application/rsd+xml"/>
#  <link href="//creativecommons.org/licenses/by-sa/3.0/" rel="license"/>
#  <link href="https://en.wikipedia.org/wiki/Undefined_behavior" rel="canonical"/>
#  <link href="//login.wikimedia.org" rel="dns-prefetch"/>
#  <link href="//meta.wikimedia.org" rel="dns-prefetch"/>
#  </head>
#  <body class="mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-Undefined_behavior rootpage-Undefined_behavior skin-vector action-view skin-vector-legacy"><div class="noprint" id="mw-page-base"></div>
#  <div class="noprint" id="mw-head-base"></div>
#  <div class="mw-body" id="content" role="main">
#  <a id="top"></a>
#  <div class="mw-body-content" id="siteNotice"><!-- CentralNotice --></div>
#  <div class="mw-indicators mw-body-content">
#  </div>
#  <h1 class="firstHeading" id="firstHeading" lang="en">Undefined behavior</h1>
#  <div class="mw-body-content" id="bodyContent">
#  <div class="noprint" id="siteSub">From Wikipedia, the free encyclopedia</div>
#  <div id="contentSub"></div>
#  <div id="contentSub2"></div>
#  <div id="jump-to-nav"></div>
#  <a class="mw-jump-link" href="#mw-head">Jump to navigation</a>
#  <a class="mw-jump-link" href="#searchInput">Jump to search</a>
#  <div class="mw-content-ltr" dir="ltr" id="mw-content-text" lang="en"><div class="mw-parser-output"><div class="hatnote navigation-not-searchable" role="note">Not to be confused with <a href="/wiki/Undefined_value" title="Undefined value">Undefined value</a> or <a href="/wiki/Unspecified_behavior" title="Unspecified behavior">Unspecified behavior</a>.</div>
#  <p>In <a href="/wiki/Computer_programming" title="Computer programming">computer programming</a>, <b>undefined behavior</b> (<b>UB</b>) is the result of executing a program whose <a href="/wiki/Behavior" title="Behavior">behavior</a> is prescribed to be unpredictable, in the <a class="mw-redirect" href="/wiki/Language_specification" title="Language specification">language specification</a> to which the <a class="mw-redirect" href="/wiki/Computer_code" title="Computer code">computer code</a> adheres. This is different from <a href="/wiki/Unspecified_behavior" title="Unspecified behavior">unspecified behavior</a>, for which the language specification does not prescribe a result and implementation defined behavior that defers to the documentation of another component of the <a class="mw-redirect" href="/wiki/Platform_(computing)" title="Platform (computing)">platform</a> (such as the <a href="/wiki/Application_binary_interface" title="Application binary interface">ABI</a> or the <a href="/wiki/Translator_(computing)" title="Translator (computing)">translator</a> documentation).
#  </p><p>In the <a href="/wiki/C_(programming_language)" title="C (programming language)">C community</a>, undefined behavior may be humorously referred to as "<b>nasal demons</b>", after a <a href="/wiki/Usenet" title="Usenet">comp.std.c</a> post that explained undefined behavior as allowing the compiler to do anything it chooses, even "to make demons fly out of your nose".<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>
#  </p>
#  <div aria-labelledby="mw-toc-heading" class="toc" id="toc" role="navigation"><input class="toctogglecheckbox" id="toctogglecheckbox" role="button" style="display:none" type="checkbox"/><div class="toctitle" dir="ltr" lang="en"><h2 id="mw-toc-heading">Contents</h2><span class="toctogglespan"><label class="toctogglelabel" for="toctogglecheckbox"></label></span></div>
#  <ul>
#  <li class="toclevel-1 tocsection-1"><a href="#Overview"><span class="tocnumber">1</span> <span class="toctext">Overview</span></a></li>
#  <li class="toclevel-1 tocsection-2"><a href="#Benefits"><span class="tocnumber">2</span> <span class="toctext">Benefits</span></a></li>
#  <li class="toclevel-1 tocsection-3"><a href="#Risks"><span class="tocnumber">3</span> <span class="toctext">Risks</span></a></li>
#  <li class="toclevel-1 tocsection-4"><a href="#Examples_in_C_and_C++"><span class="tocnumber">4</span> <span class="toctext">Examples in C and C++</span></a></li>
#  <li class="toclevel-1 tocsection-5"><a href="#See_also"><span class="tocnumber">5</span> <span class="toctext">See also</span></a></li>
#  <li class="toclevel-1 tocsection-6"><a href="#References"><span class="tocnumber">6</span> <span class="toctext">References</span></a></li>
#  <li class="toclevel-1 tocsection-7"><a href="#Further_reading"><span class="tocnumber">7</span> <span class="toctext">Further reading</span></a></li>
#  <li class="toclevel-1 tocsection-8"><a href="#External_links"><span class="tocnumber">8</span> <span class="toctext">External links</span></a></li>
#  </ul>
#  </div>
#  <h2><span class="mw-headline" id="Overview">Overview</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Undefined_behavior&amp;action=edit&amp;section=1" title="Edit section: Overview">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
#  <p>Some <a href="/wiki/Programming_language" title="Programming language">programming languages</a> allow a program to operate differently or even have a different control flow than the <a href="/wiki/Source_code" title="Source code">source code</a>, as long as it exhibits the same user-visible <a href="/wiki/Side_effect_(computer_science)" title="Side effect (computer science)">side effects</a>, <i>if undefined behavior never happens during program execution</i>. Undefined behavior is the name of a list of conditions that the program must not meet.
#  </p><p>In the early versions of <a href="/wiki/C_(programming_language)" title="C (programming language)">C</a>, undefined behavior's primary advantage was the production of performant <a href="/wiki/Compiler" title="Compiler">compilers</a> for a wide variety of machines: a specific construct could be mapped to a machine-specific feature, and the compiler did not have to generate additional code for the runtime to adapt the side effects to match semantics imposed by the language. The program source code was written with prior knowledge of the specific compiler and of the <a class="mw-redirect" href="/wiki/Platform_(computing)" title="Platform (computing)">platforms</a> that it would support.
#  </p><p>However, progressive standardization of the platforms has made this less of an advantage, especially in newer versions of C. Now, the cases for undefined behavior typically represent unambiguous <a class="mw-redirect" href="/wiki/Software_bugs" title="Software bugs">bugs</a> in the code, for example indexing an array outside of its bounds. By definition, the <a href="/wiki/Runtime_system" title="Runtime system">runtime</a> can assume that undefined behavior never happens; therefore, some invalid conditions do not need to be checked against. For a <a href="/wiki/Compiler" title="Compiler">compiler</a>, this also means that various <a class="mw-redirect" href="/wiki/Program_transformations" title="Program transformations">program transformations</a> become valid, or their proofs of correctness are simplified; this allows for various kinds of <a class="mw-redirect" href="/wiki/Premature_optimization" title="Premature optimization">premature optimization</a> and <a class="new" href="/w/index.php?title=Micro-optimization&amp;action=edit&amp;redlink=1" title="Micro-optimization (page does not exist)">micro-optimization</a>, which lead to incorrect behavior if the program state meets any of such conditions. The compiler can also remove explicit checks that may have been in the source code, without notifying the programmer; for example, detecting undefined behavior by testing whether it happened is not guaranteed to work, by definition. This makes it hard or impossible to program a portable fail-safe option (non-portable solutions are possible for some constructs).
#  </p><p>Current compiler development usually evaluates and compares compiler performance with benchmarks designed around micro-optimizations, even on platforms that are mostly used on the general-purpose desktop and laptop market (such as amd64). Therefore, undefined behavior provides ample room for compiler performance improvement, as the source code for a specific source code statement is allowed to be mapped to anything at runtime.
#  </p><p>For C and C++, the compiler is allowed to give a compile-time diagnostic in these cases, but is not required to: the implementation will be considered correct whatever it does in such cases, analogous to <a href="/wiki/Don%27t-care_term" title="Don't-care term">don't-care terms</a> in digital logic. It is the responsibility of the programmer to write code that never invokes undefined behavior, although compiler implementations are allowed to issue diagnostics when this happens. Compilers nowadays have flags that enable such diagnostics, for example, <code>-fsanitize</code> enables the "undefined behavior sanitizer" (<a class="new" href="/w/index.php?title=UBSan&amp;action=edit&amp;redlink=1" title="UBSan (page does not exist)">UBSan</a>) in <a href="/wiki/GNU_Compiler_Collection" title="GNU Compiler Collection">gcc</a> 4.9<sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup> and in <a href="/wiki/Clang" title="Clang">clang</a>. However, this flag is not the default and enabling it is a choice of who builds the code.
#  </p><p>Under some circumstances there can be specific restrictions on undefined behavior. For example, the <a class="mw-redirect" href="/wiki/Instruction_set" title="Instruction set">instruction set</a> specifications of a <a href="/wiki/Central_processing_unit" title="Central processing unit">CPU</a> might leave the behavior of some forms of an instruction undefined, but if the CPU supports <a href="/wiki/Memory_protection" title="Memory protection">memory protection</a> then the specification will probably include a blanket rule stating that no user-accessible instruction may cause a hole in the <a href="/wiki/Operating_system" title="Operating system">operating system</a>'s security; so an actual CPU would be permitted to corrupt user registers in response to such an instruction, but would not be allowed to, for example, switch into <a class="mw-redirect" href="/wiki/Supervisor_mode" title="Supervisor mode">supervisor mode</a>.
#  </p><p>The runtime <a class="mw-redirect" href="/wiki/Platform_(computing)" title="Platform (computing)">platform</a> can also provide some restrictions or guarantees on undefined behavior, if the <a href="/wiki/Toolchain" title="Toolchain">toolchain</a> or the <a href="/wiki/Runtime_system" title="Runtime system">runtime</a> explicitly document that specific constructs found in the <a href="/wiki/Source_code" title="Source code">source code</a> are mapped to specific well-defined mechanisms available at runtime. For example, an <a href="/wiki/Interpreter_(computing)" title="Interpreter (computing)">interpreter</a> may document a certain behavior for some operations that are undefined in the language specification, while other interpreters or compilers for the same language may not. A <a href="/wiki/Compiler" title="Compiler">compiler</a> produces <a class="mw-redirect" href="/wiki/Executable_code" title="Executable code">executable code</a> for a specific <a href="/wiki/Application_binary_interface" title="Application binary interface">ABI</a>, filling the <a href="/wiki/Semantic_gap" title="Semantic gap">semantic gap</a> in ways that depend on the compiler version: the documentation for that compiler version and the ABI specification can provide restrictions on undefined behavior. Relying on these implementation details makes the software non-<a href="/wiki/Portable_application" title="Portable application">portable</a>, however portability may not be a concern if the software is not supposed to be used outside of a specific runtime.
#  </p><p>Undefined behavior can result in a program crash or even in failures that are harder to detect and make the program look like it is working normally, such as silent loss of data and production of incorrect results.
#  </p>
#  <h2><span class="mw-headline" id="Benefits">Benefits</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Undefined_behavior&amp;action=edit&amp;section=2" title="Edit section: Benefits">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
#  <p>Documenting an operation as undefined behavior allows compilers to assume that this operation will never happen in a conforming program. This gives the compiler more information about the code and this information can lead to more optimization opportunities.
#  </p><p>An example for the C language:
#  </p>
#  <div class="mw-highlight mw-highlight-lang-c mw-content-ltr" dir="ltr"><pre><span></span><span class="kt">int</span> <span class="nf">foo</span><span class="p">(</span><span class="kt">unsigned</span> <span class="kt">char</span> <span class="n">x</span><span class="p">)</span>
#  <span class="p">{</span>
#       <span class="kt">int</span> <span class="n">value</span> <span class="o">=</span> <span class="mi">2147483600</span><span class="p">;</span> <span class="cm">/* assuming 32-bit int and 8-bit char */</span>
#       <span class="n">value</span> <span class="o">+=</span> <span class="n">x</span><span class="p">;</span>
#       <span class="k">if</span> <span class="p">(</span><span class="n">value</span> <span class="o">&lt;</span> <span class="mi">2147483600</span><span class="p">)</span>
#          <span class="n">bar</span><span class="p">();</span>
#       <span class="k">return</span> <span class="n">value</span><span class="p">;</span>
#  <span class="p">}</span>
#  </pre></div>
#  <p>The value of <code>x</code> cannot be negative and, given that signed <a href="/wiki/Integer_overflow" title="Integer overflow">integer overflow</a> is undefined behavior in C, the compiler can assume that <code>value &lt; 2147483600</code> will always be false. Thus the <code>if</code> statement, including  the call to the function <code>bar</code>, can be ignored by the compiler since the test expression in the <code>if</code> has no <a href="/wiki/Side_effect_(computer_science)" title="Side effect (computer science)">side effects</a> and its condition will never be satisfied. The code is therefore semantically equivalent to:
#  </p>
#  <div class="mw-highlight mw-highlight-lang-c mw-content-ltr" dir="ltr"><pre><span></span><span class="kt">int</span> <span class="nf">foo</span><span class="p">(</span><span class="kt">unsigned</span> <span class="kt">char</span> <span class="n">x</span><span class="p">)</span>
#  <span class="p">{</span>
#       <span class="kt">int</span> <span class="n">value</span> <span class="o">=</span> <span class="mi">2147483600</span><span class="p">;</span>
#       <span class="n">value</span> <span class="o">+=</span> <span class="n">x</span><span class="p">;</span>
#       <span class="k">return</span> <span class="n">value</span><span class="p">;</span>
#  <span class="p">}</span>
#  </pre></div>
#  <p>Had the compiler been forced to assume that signed integer overflow has <i>wraparound</i> behavior, then the transformation above would not have been legal.
#  </p><p>Such optimizations become hard to spot by humans when the code is more complex and other optimizations, like <a class="mw-redirect" href="/wiki/Inlining" title="Inlining">inlining</a>, take place. For example, another function may call the above function:
#  </p>
#  <div class="mw-highlight mw-highlight-lang-c mw-content-ltr" dir="ltr"><pre><span></span><span class="kt">void</span> <span class="nf">run_tasks</span><span class="p">(</span><span class="kt">unsigned</span> <span class="kt">char</span> <span class="o">*</span><span class="n">ptrx</span><span class="p">)</span> <span class="p">{</span>
#      <span class="kt">int</span> <span class="n">z</span><span class="p">;</span>
#      <span class="n">z</span> <span class="o">=</span> <span class="n">foo</span><span class="p">(</span><span class="o">*</span><span class="n">ptrx</span><span class="p">);</span>
#      <span class="k">while</span> <span class="p">(</span><span class="o">*</span><span class="n">ptrx</span> <span class="o">&gt;</span> <span class="mi">60</span><span class="p">)</span> <span class="p">{</span>
#          <span class="n">run_one_task</span><span class="p">(</span><span class="n">ptrx</span><span class="p">,</span> <span class="n">z</span><span class="p">);</span>
#      <span class="p">}</span>
#  <span class="p">}</span>
#  </pre></div>
#  <p>The compiler is free to optimize away the <code>while</code>-loop here by applying <a href="/wiki/Value_range_analysis" title="Value range analysis">value range analysis</a>: by inspecting <code>foo()</code>, it knows that the initial value pointed to by <code>ptrx</code> cannot possibly exceed 47 (as any more would trigger undefined behavior in <code>foo()</code>), therefore the initial check of <code>*ptrx &gt; 60</code> will always be false in a conforming program. Going further, since the result <code>z</code> is now never used and <code>foo()</code> has no side effects, the compiler can optimize <code>run_tasks()</code> to be an empty function that returns immediately. The disappearance of the <code>while</code>-loop may be especially surprising if <code>foo()</code> is defined in a <a href="/wiki/Interprocedural_optimization" title="Interprocedural optimization">separately compiled object file</a>.
#  </p><p>Another benefit from allowing signed integer overflow to be undefined is that it makes it possible to store and manipulate a variable's value in a <a href="/wiki/Processor_register" title="Processor register">processor register</a> that is larger than the size of the variable in the source code. For example, if the type of a variable as specified in the source code is narrower than the native register width (such as "<a href="/wiki/C_data_types#Basic_types" title="C data types">int</a>" on a <a class="mw-redirect" href="/wiki/64-bit" title="64-bit">64-bit</a> machine, a common scenario), then the compiler can safely use a signed 64-bit integer for the variable in the <a href="/wiki/Machine_code" title="Machine code">machine code</a> it produces, without changing the defined behavior of the code. If a program depended on the behavior of a 32-bit integer overflow, then a compiler would have to insert additional logic when compiling for a 64-bit machine, because the overflow behavior of most machine instructions depends on the register width.<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>
#  </p><p>Undefined behavior also allows more compile-time checks by both compilers and <a href="/wiki/Static_program_analysis" title="Static program analysis">static program analysis</a>.<sup class="noprint Inline-Template Template-Fact" style="white-space:nowrap;">[<i><a href="/wiki/Wikipedia:Citation_needed" title="Wikipedia:Citation needed"><span title="This claim needs references to reliable sources. (December 2019)">citation needed</span></a></i>]</sup>
#  </p>
#  <h2><span class="mw-headline" id="Risks">Risks</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Undefined_behavior&amp;action=edit&amp;section=3" title="Edit section: Risks">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
#  <p>C and C++ standards have several forms of undefined behavior throughout, which offer increased liberty in compiler implementations and compile-time checks at the expense of undefined run-time behavior if present. In particular, the <a href="/wiki/International_Organization_for_Standardization" title="International Organization for Standardization">ISO</a> standard for C has an appendix listing common sources of undefined behavior.<sup class="reference" id="cite_ref-4"><a href="#cite_note-4">[4]</a></sup> Moreover, compilers are not required to diagnose code that relies on undefined behavior. Hence, it is common for programmers, even experienced ones, to rely on undefined behavior either by mistake, or simply because they are not well-versed in the rules of the language that can span hundreds of pages. This can result in bugs that are exposed when a different compiler, or different settings, are used. Testing or <a href="/wiki/Fuzzing" title="Fuzzing">fuzzing</a> with dynamic undefined behavior checks enabled, e.g., the <a href="/wiki/Clang" title="Clang">Clang</a> sanitizers, can help to catch undefined behavior not diagnosed by the compiler or static analyzers.<sup class="reference" id="cite_ref-5"><a href="#cite_note-5">[5]</a></sup>
#  </p><p>Undefined behavior can lead to <a href="/wiki/Computer_security" title="Computer security">security</a> vulnerabilities in software. For example, buffer overflows and other security vulnerabilities in the major <a href="/wiki/Web_browser" title="Web browser">web browsers</a> are due to undefined behavior. The <a href="/wiki/Year_2038_problem" title="Year 2038 problem">Year 2038 problem</a> is another example due to <a class="mw-redirect" href="/wiki/Signed_integer" title="Signed integer">signed</a> <a href="/wiki/Integer_overflow" title="Integer overflow">integer overflow</a>. When <a class="mw-redirect" href="/wiki/GNU_C_Compiler" title="GNU C Compiler">GCC</a>'s developers changed their compiler in 2008 such that it omitted certain overflow checks that relied on undefined behavior, <a href="/wiki/CERT_Coordination_Center" title="CERT Coordination Center">CERT</a> issued a warning against the newer versions of the compiler.<sup class="reference" id="cite_ref-6"><a href="#cite_note-6">[6]</a></sup> <a class="mw-redirect" href="/wiki/Linux_Weekly_News" title="Linux Weekly News">Linux Weekly News</a> pointed out that the same behavior was observed in <a href="/wiki/PathScale" title="PathScale">PathScale C</a>, <a class="mw-redirect" href="/wiki/Visual_C%2B%2B" title="Visual C++">Microsoft Visual C++ 2005</a> and several other compilers;<sup class="reference" id="cite_ref-7"><a href="#cite_note-7">[7]</a></sup> the warning was later amended to warn about various compilers.<sup class="reference" id="cite_ref-8"><a href="#cite_note-8">[8]</a></sup>
#  </p>
#  <h2><span id="Examples_in_C_and_C.2B.2B"></span><span class="mw-headline" id="Examples_in_C_and_C++">Examples in C and C++</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Undefined_behavior&amp;action=edit&amp;section=4" title="Edit section: Examples in C and C++">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
#  <p>The major forms of undefined behavior in C can be broadly classified as:<sup class="reference" id="cite_ref-9"><a href="#cite_note-9">[9]</a></sup> spatial memory safety violations, temporal memory safety violations, <a href="/wiki/Integer_overflow" title="Integer overflow">integer overflow</a>, strict aliasing violations, alignment violations, unsequenced modifications, data races, and loops that neither perform I/O nor terminate.
#  </p><p>In C the use of any <a href="/wiki/Automatic_variable" title="Automatic variable">automatic variable</a> before it has been initialized yields undefined behavior, as does integer <a href="/wiki/Division_by_zero" title="Division by zero">division by zero</a>, signed integer overflow, indexing an array outside of its defined bounds (see <a href="/wiki/Buffer_overflow" title="Buffer overflow">buffer overflow</a>), or <a href="/wiki/Null_pointer" title="Null pointer">null pointer</a> <a href="/wiki/Dereference_operator" title="Dereference operator">dereferencing</a>. In general, any instance of undefined behavior leaves the abstract execution machine in an unknown state, and causes the behavior of the entire program to be undefined.
#  </p><p>Attempting to modify a <a href="/wiki/String_literal" title="String literal">string literal</a> causes undefined behavior:<sup class="reference" id="cite_ref-C++03_2.13.4/2_10-0"><a href="#cite_note-C++03_2.13.4/2-10">[10]</a></sup>
#  </p>
#  <div class="mw-highlight mw-highlight-lang-cpp mw-content-ltr" dir="ltr"><pre><span></span><span class="kt">char</span> <span class="o">*</span><span class="n">p</span> <span class="o">=</span> <span class="s">"wikipedia"</span><span class="p">;</span> <span class="c1">// valid C, deprecated in C++98/C++03, ill-formed as of C++11</span>
#  <span class="n">p</span><span class="p">[</span><span class="mi">0</span><span class="p">]</span> <span class="o">=</span> <span class="sc">'W'</span><span class="p">;</span> <span class="c1">// undefined behavior</span>
#  </pre></div>
#  <p>Integer <a href="/wiki/Division_by_zero" title="Division by zero">division by zero</a> results in undefined behavior:<sup class="reference" id="cite_ref-C++03_5.6/4_11-0"><a href="#cite_note-C++03_5.6/4-11">[11]</a></sup>
#  </p>
#  <div class="mw-highlight mw-highlight-lang-cpp mw-content-ltr" dir="ltr"><pre><span></span><span class="kt">int</span> <span class="n">x</span> <span class="o">=</span> <span class="mi">1</span><span class="p">;</span>
#  <span class="k">return</span> <span class="n">x</span> <span class="o">/</span> <span class="mi">0</span><span class="p">;</span> <span class="c1">// undefined behavior</span>
#  </pre></div>
#  <p>Certain pointer operations may result in undefined behavior:<sup class="reference" id="cite_ref-C++03_5.6/5_12-0"><a href="#cite_note-C++03_5.6/5-12">[12]</a></sup>
#  </p>
#  <div class="mw-highlight mw-highlight-lang-cpp mw-content-ltr" dir="ltr"><pre><span></span><span class="kt">int</span> <span class="n">arr</span><span class="p">[</span><span class="mi">4</span><span class="p">]</span> <span class="o">=</span> <span class="p">{</span><span class="mi">0</span><span class="p">,</span> <span class="mi">1</span><span class="p">,</span> <span class="mi">2</span><span class="p">,</span> <span class="mi">3</span><span class="p">};</span>
#  <span class="kt">int</span> <span class="o">*</span><span class="n">p</span> <span class="o">=</span> <span class="n">arr</span> <span class="o">+</span> <span class="mi">5</span><span class="p">;</span>  <span class="c1">// undefined behavior for indexing out of bounds</span>
#  <span class="n">p</span> <span class="o">=</span> <span class="mi">0</span><span class="p">;</span>
#  <span class="kt">int</span> <span class="n">a</span> <span class="o">=</span> <span class="o">*</span><span class="n">p</span><span class="p">;</span>        <span class="c1">// undefined behavior for dereferencing a null pointer</span>
#  </pre></div>
#  <p>In C and C++, the relational comparison of <a href="/wiki/Pointer_(computer_programming)" title="Pointer (computer programming)">pointers</a> to objects (for less-than or greater-than comparison) is only strictly defined if the pointers point to members of the same object, or elements of the same <a href="/wiki/Array_data_structure" title="Array data structure">array</a>.<sup class="reference" id="cite_ref-C++03_5.9/2_13-0"><a href="#cite_note-C++03_5.9/2-13">[13]</a></sup> Example:
#  </p>
#  <div class="mw-highlight mw-highlight-lang-cpp mw-content-ltr" dir="ltr"><pre><span></span><span class="kt">int</span> <span class="nf">main</span><span class="p">(</span><span class="kt">void</span><span class="p">)</span>
#  <span class="p">{</span>
#    <span class="kt">int</span> <span class="n">a</span> <span class="o">=</span> <span class="mi">0</span><span class="p">;</span>
#    <span class="kt">int</span> <span class="n">b</span> <span class="o">=</span> <span class="mi">0</span><span class="p">;</span>
#    <span class="k">return</span> <span class="o">&amp;</span><span class="n">a</span> <span class="o">&lt;</span> <span class="o">&amp;</span><span class="n">b</span><span class="p">;</span> <span class="cm">/* undefined behavior */</span>
#  <span class="p">}</span>
#  </pre></div>
#  <p>Reaching the end of a value-returning function (other than <code>main()</code>) without a return statement results in undefined behavior if the value of the function call is used by the caller:<sup class="reference" id="cite_ref-C99_6.9.1/12_14-0"><a href="#cite_note-C99_6.9.1/12-14">[14]</a></sup>
#  </p>
#  <div class="mw-highlight mw-highlight-lang-c mw-content-ltr" dir="ltr"><pre><span></span><span class="kt">int</span> <span class="nf">f</span><span class="p">()</span>
#  <span class="p">{</span>
#  <span class="p">}</span>  <span class="cm">/* undefined behavior if the value of the function call is used*/</span>
#  </pre></div>
#  <p>Modifying an object between two <a href="/wiki/Sequence_point" title="Sequence point">sequence points</a> more than once produces undefined behavior.<sup class="reference" id="cite_ref-15"><a href="#cite_note-15">[15]</a></sup> There are considerable changes in what causes undefined behavior in relation to sequence points as of C++11.<sup class="reference" id="cite_ref-:0_16-0"><a href="#cite_note-:0-16">[16]</a></sup> The following example will however cause undefined behavior in both C++ and C.
#  </p>
#  <div class="mw-highlight mw-highlight-lang-c mw-content-ltr" dir="ltr"><pre><span></span><span class="n">i</span> <span class="o">=</span> <span class="n">i</span><span class="o">++</span> <span class="o">+</span> <span class="mi">1</span><span class="p">;</span> <span class="c1">// undefined behavior</span>
#  </pre></div>
#  <p>When modifying an object between two sequence points, reading the value of the object for any other purpose than determining the value to be stored is also undefined behavior.<sup class="reference" id="cite_ref-C99_6.5/2_17-0"><a href="#cite_note-C99_6.5/2-17">[17]</a></sup>
#  </p>
#  <div class="mw-highlight mw-highlight-lang-c mw-content-ltr" dir="ltr"><pre><span></span><span class="n">a</span><span class="p">[</span><span class="n">i</span><span class="p">]</span> <span class="o">=</span> <span class="n">i</span><span class="o">++</span><span class="p">;</span> <span class="c1">// undefined behavior</span>
#  <span class="n">printf</span><span class="p">(</span><span class="s">"%d %d</span><span class="se">\n</span><span class="s">"</span><span class="p">,</span> <span class="o">++</span><span class="n">n</span><span class="p">,</span> <span class="n">power</span><span class="p">(</span><span class="mi">2</span><span class="p">,</span> <span class="n">n</span><span class="p">));</span> <span class="c1">// also undefined behavior</span>
#  </pre></div>
#  <p>In C/C++ <a href="/wiki/Logical_shift" title="Logical shift">bitwise shifting</a> a value by a number of bits which is either a negative number or is greater than or equal to the total number of bits in this value results in undefined behavior. The safest way (regardless of compiler vendor) is to always keep the number of bits to shift (the right operand of the <code>&lt;&lt;</code> and <code>&gt;&gt;</code> <a href="/wiki/Bitwise_operation" title="Bitwise operation">bitwise operators</a>) within the range: &lt;<code>0, <a href="/wiki/Sizeof" title="Sizeof">sizeof</a>(value)*CHAR_BIT - 1</code>&gt; (where <code>value</code> is the left operand).
#  </p>
#  <div class="mw-highlight mw-highlight-lang-c mw-content-ltr" dir="ltr"><pre><span></span><span class="kt">int</span> <span class="n">num</span> <span class="o">=</span> <span class="o">-</span><span class="mi">1</span><span class="p">;</span>
#  <span class="kt">unsigned</span> <span class="kt">int</span> <span class="n">val</span> <span class="o">=</span> <span class="mi">1</span> <span class="o">&lt;&lt;</span> <span class="n">num</span><span class="p">;</span> <span class="c1">//shifting by a negative number - undefined behavior</span>
#
#  <span class="n">num</span> <span class="o">=</span> <span class="mi">32</span><span class="p">;</span> <span class="c1">//or whatever number greater than 31</span>
#  <span class="n">val</span> <span class="o">=</span> <span class="mi">1</span> <span class="o">&lt;&lt;</span> <span class="n">num</span><span class="p">;</span> <span class="c1">//the literal '1' is typed as a 32-bit integer - in this case shifting by more than 31 bits is undefined behavior</span>
#
#  <span class="n">num</span> <span class="o">=</span> <span class="mi">64</span><span class="p">;</span> <span class="c1">//or whatever number greater than 63</span>
#  <span class="kt">unsigned</span> <span class="kt">long</span> <span class="kt">long</span> <span class="n">val2</span> <span class="o">=</span> <span class="mi">1ULL</span> <span class="o">&lt;&lt;</span> <span class="n">num</span><span class="p">;</span> <span class="c1">//the literal '1ULL' is typed as a 64-bit integer - in this case shifting by more than 63 bits is undefined behavior</span>
#  </pre></div>
#  <h2><span class="mw-headline" id="See_also">See also</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Undefined_behavior&amp;action=edit&amp;section=5" title="Edit section: See also">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
#  <ul><li><a href="/wiki/Compiler" title="Compiler">Compiler</a></li>
#  <li><a href="/wiki/Halt_and_Catch_Fire_(computing)" title="Halt and Catch Fire (computing)">Halt and Catch Fire</a></li>
#  <li><a href="/wiki/Unspecified_behavior" title="Unspecified behavior">Unspecified behavior</a></li></ul>
#  <h2><span class="mw-headline" id="References">References</span><span class="mw-editsection"><span class="mw-editsection-bracket">[</span><a href="/w/index.php?title=Undefined_behavior&amp;action=edit&amp;section=6" title="Edit section: References">edit</a><span class="mw-editsection-bracket">]</span></span></h2>
#  <div class="reflist columns references-column-width" style="-moz-column-width: 30em; -webkit-column-width: 30em; column-width: 30em; list-style-type: decimal;">
#  <ol class="references">
#  <li id="cite_note-1"><span class="mw-cite-backlink"><b><a href="#cite_ref-1">^</a></b></span> <span class="reference-text"><cite class="citation web cs1"><a class="external text" href="http://catb.org/jargon/html/N/nasal-demons.html" rel="nofollow">"nasal demons"</a>. <i><a href="/wiki/Jargon_File" title="Jargon File">Jargon File</a></i><span class="reference-accessdate">. Retrieved <span class="nowrap">12 June</span> 2014</span>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Jargon+File&amp;rft.atitle=nasal+demons&amp;rft_id=http%3A%2F%2Fcatb.org%2Fjargon%2Fhtml%2FN%2Fnasal-demons.html&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AUndefined+behavior"></span><style data-mw-deduplicate="TemplateStyles:r982806391">.mw-parser-output cite.citation{font-style:inherit}.mw-parser-output .citation q{quotes:"\"""\"""'""'"}.mw-parser-output .id-lock-free a,.mw-parser-output .citation .cs1-lock-free a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/6/65/Lock-green.svg")right 0.1em center/9px no-repeat}.mw-parser-output .id-lock-limited a,.mw-parser-output .id-lock-registration a,.mw-parser-output .citation .cs1-lock-limited a,.mw-parser-output .citation .cs1-lock-registration a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/d/d6/Lock-gray-alt-2.svg")right 0.1em center/9px no-repeat}.mw-parser-output .id-lock-subscription a,.mw-parser-output .citation .cs1-lock-subscription a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/a/aa/Lock-red-alt-2.svg")right 0.1em center/9px no-repeat}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration{color:#555}.mw-parser-output .cs1-subscription span,.mw-parser-output .cs1-registration span{border-bottom:1px dotted;cursor:help}.mw-parser-output .cs1-ws-icon a{background:linear-gradient(transparent,transparent),url("//upload.wikimedia.org/wikipedia/commons/4/4c/Wikisource-logo.svg")right 0.1em center/12px no-repeat}.mw-parser-output code.cs1-code{color:inherit;background:inherit;border:none;padding:inherit}.mw-parser-output .cs1-hidden-error{display:none;font-size:100%}.mw-parser-output .cs1-visible-error{font-size:100%}.mw-parser-output .cs1-maint{display:none;color:#33aa33;margin-left:0.3em}.mw-parser-output .cs1-subscription,.mw-parser-output .cs1-registration,.mw-parser-output .cs1-format{font-size:95%}.mw-parser-output .cs1-kern-left,.mw-parser-output .cs1-kern-wl-left{padding-left:0.2em}.mw-parser-output .cs1-kern-right,.mw-parser-output .cs1-kern-wl-right{padding-right:0.2em}.mw-parser-output .citation .mw-selflink{font-weight:inherit}</style></span>
#  </li>
#  <li id="cite_note-2"><span class="mw-cite-backlink"><b><a href="#cite_ref-2">^</a></b></span> <span class="reference-text"><a class="external text" href="https://developers.redhat.com/blog/2014/10/16/gcc-undefined-behavior-sanitizer-ubsan/" rel="nofollow"><i>GCC Undefined Behavior Sanitizer – ubsan</i></a></span>
#  </li>
#  <li id="cite_note-3"><span class="mw-cite-backlink"><b><a href="#cite_ref-3">^</a></b></span> <span class="reference-text"><a class="external free" href="https://gist.github.com/rygorous/e0f055bfb74e3d5f0af20690759de5a7#file-gistfile1-txt-L166" rel="nofollow">https://gist.github.com/rygorous/e0f055bfb74e3d5f0af20690759de5a7#file-gistfile1-txt-L166</a></span>
#  </li>
#  <li id="cite_note-4"><span class="mw-cite-backlink"><b><a href="#cite_ref-4">^</a></b></span> <span class="reference-text">ISO/IEC 9899:2011 §J.2.</span>
#  </li>
#  <li id="cite_note-5"><span class="mw-cite-backlink"><b><a href="#cite_ref-5">^</a></b></span> <span class="reference-text"><cite class="citation web cs1" id="CITEREFJohn_Regehr">John Regehr. <a class="external text" href="https://www.youtube.com/watch?v=v1COuU2vU_w" rel="nofollow">"Undefined behavior in 2017, cppcon 2017"</a>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=unknown&amp;rft.btitle=Undefined+behavior+in+2017%2C+cppcon+2017&amp;rft.au=John+Regehr&amp;rft_id=https%3A%2F%2Fwww.youtube.com%2Fwatch%3Fv%3Dv1COuU2vU_w&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AUndefined+behavior"></span><link href="mw-data:TemplateStyles:r982806391" rel="mw-deduplicated-inline-style"/></span>
#  </li>
#  <li id="cite_note-6"><span class="mw-cite-backlink"><b><a href="#cite_ref-6">^</a></b></span> <span class="reference-text"><cite class="citation web cs1"><a class="external text" href="https://web.archive.org/web/20080409224149/http://www.kb.cert.org/vuls/id/162289" rel="nofollow">"Vulnerability Note VU#162289 — gcc silently discards some wraparound checks"</a>. <i>Vulnerability Notes Database</i>. CERT. 4 April 2008. Archived from <a class="external text" href="http://www.kb.cert.org/vuls/id/162289" rel="nofollow">the original</a> on 9 April 2008.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Vulnerability+Notes+Database&amp;rft.atitle=Vulnerability+Note+VU%23162289+%E2%80%94+gcc+silently+discards+some+wraparound+checks&amp;rft.date=2008-04-04&amp;rft_id=http%3A%2F%2Fwww.kb.cert.org%2Fvuls%2Fid%2F162289&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AUndefined+behavior"></span><link href="mw-data:TemplateStyles:r982806391" rel="mw-deduplicated-inline-style"/></span>
#  </li>
#  <li id="cite_note-7"><span class="mw-cite-backlink"><b><a href="#cite_ref-7">^</a></b></span> <span class="reference-text"><cite class="citation web cs1" id="CITEREFJonathan_Corbet2008">Jonathan Corbet (16 April 2008). <a class="external text" href="http://lwn.net/Articles/278137/" rel="nofollow">"GCC and pointer overflows"</a>. <i><a class="mw-redirect" href="/wiki/Linux_Weekly_News" title="Linux Weekly News">Linux Weekly News</a></i>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Linux+Weekly+News&amp;rft.atitle=GCC+and+pointer+overflows&amp;rft.date=2008-04-16&amp;rft.au=Jonathan+Corbet&amp;rft_id=http%3A%2F%2Flwn.net%2FArticles%2F278137%2F&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AUndefined+behavior"></span><link href="mw-data:TemplateStyles:r982806391" rel="mw-deduplicated-inline-style"/></span>
#  </li>
#  <li id="cite_note-8"><span class="mw-cite-backlink"><b><a href="#cite_ref-8">^</a></b></span> <span class="reference-text"><cite class="citation web cs1"><a class="external text" href="http://www.kb.cert.org/vuls/id/162289" rel="nofollow">"Vulnerability Note VU#162289 — C compilers may silently discard some wraparound checks"</a>. <i>Vulnerability Notes Database</i>. CERT. 8 October 2008 [4 April 2008].</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Ajournal&amp;rft.genre=unknown&amp;rft.jtitle=Vulnerability+Notes+Database&amp;rft.atitle=Vulnerability+Note+VU%23162289+%E2%80%94+C+compilers+may+silently+discard+some+wraparound+checks&amp;rft.date=2008-10-08&amp;rft_id=http%3A%2F%2Fwww.kb.cert.org%2Fvuls%2Fid%2F162289&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AUndefined+behavior"></span><link href="mw-data:TemplateStyles:r982806391" rel="mw-deduplicated-inline-style"/></span>
#  </li>
#  <li id="cite_note-9"><span class="mw-cite-backlink"><b><a href="#cite_ref-9">^</a></b></span> <span class="reference-text"><cite class="citation web cs1" id="CITEREFPascal_Cuoq_and_John_Regehr2017">Pascal Cuoq and John Regehr (4 July 2017). <a class="external text" href="https://blog.regehr.org/archives/1520" rel="nofollow">"Undefined Behavior in 2017, Embedded in Academia Blog"</a>.</cite><span class="Z3988" title="ctx_ver=Z39.88-2004&amp;rft_val_fmt=info%3Aofi%2Ffmt%3Akev%3Amtx%3Abook&amp;rft.genre=unknown&amp;rft.btitle=Undefined+Behavior+in+2017%2C+Embedded+in+Academia+Blog&amp;rft.date=2017-07-04&amp;rft.au=Pascal+Cuoq+and+John+Regehr&amp;rft_id=https%3A%2F%2Fblog.regehr.org%2Farchives%2F1520&amp;rfr_id=info%3Asid%2Fen.wikipedia.org%3AUndefined+behavior"></span><link href="mw-data:TemplateStyles:r982806391" rel="mw-deduplicated-inline-style"/></span>
#  </li>
#  <li id="cite_note-C++03_2.13.4/2-10"><span class="mw-cite-backlink"><b><a href="#cite_ref-C++03_2.13.4/2_10-0">^</a></b></span> <span class="reference-text"><a href="/wiki/International_Organization_for_Standardization" title="International Organization for Standardization">ISO</a>/<a href="/wiki/International_Electrotechnical_Commission" title="International Electrotechnical Commission">IEC</a> (2003). <i><a class="mw-redirect" href="/wiki/ISO/IEC_14882" title="ISO/IEC 14882">ISO/IEC 14882:2003(E): Programming Languages - C++</a> §2.13.4 String literals [lex.string]</i> para. 2</span>
#  </li>
#  <li id="cite_note-C++03_5.6/4-11"><span class="mw-cite-backlink"><b><a href="#cite_ref-C++03_5.6/4_11-0">^</a></b></span> <span class="reference-text"><a href="/wiki/International_Organization_for_Standardization" title="International Organization for Standardization">ISO</a>/<a href="/wiki/International_Electrotechnical_Commission" title="International Electrotechnical Commission">IEC</a> (2003). <i><a class="mw-redirect" href="/wiki/ISO/IEC_14882" title="ISO/IEC 14882">ISO/IEC 14882:2003(E): Programming Languages - C++</a> §5.6 Multiplicative operators [expr.mul]</i> para. 4</span>
#  </li>
# ...
#  </div>
#  </nav>
#  <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#  <nav aria-labelledby="p-interaction-label" class="mw-portlet mw-portlet-interaction vector-menu vector-menu-portal portal" id="p-interaction" role="navigation">
#  <h3 id="p-interaction-label">
#  <span>Contribute</span>
#  </h3>
#  <div class="vector-menu-content">
#  <ul class="vector-menu-content-list"><li id="n-help"><a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia">Help</a></li><li id="n-introduction"><a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia">Learn to edit</a></li><li id="n-portal"><a href="/wiki/Wikipedia:Community_portal" title="The hub for editors">Community portal</a></li><li id="n-recentchanges"><a accesskey="r" href="/wiki/Special:RecentChanges" title="A list of recent changes to Wikipedia [r]">Recent changes</a></li><li id="n-upload"><a href="/wiki/Wikipedia:File_Upload_Wizard" title="Add images or other media for use on Wikipedia">Upload file</a></li></ul>
#  </div>
#  </nav>
#  <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#  <nav aria-labelledby="p-tb-label" class="mw-portlet mw-portlet-tb vector-menu vector-menu-portal portal" id="p-tb" role="navigation">
#  <h3 id="p-tb-label">
#  <span>Tools</span>
#  </h3>
#  <div class="vector-menu-content">
#  <ul class="vector-menu-content-list"><li id="t-whatlinkshere"><a accesskey="j" href="/wiki/Special:WhatLinksHere/Undefined_behavior" title="List of all English Wikipedia pages containing links to this page [j]">What links here</a></li><li id="t-recentchangeslinked"><a accesskey="k" href="/wiki/Special:RecentChangesLinked/Undefined_behavior" rel="nofollow" title="Recent changes in pages linked from this page [k]">Related changes</a></li><li id="t-upload"><a accesskey="u" href="/wiki/Wikipedia:File_Upload_Wizard" title="Upload files [u]">Upload file</a></li><li id="t-specialpages"><a accesskey="q" href="/wiki/Special:SpecialPages" title="A list of all special pages [q]">Special pages</a></li><li id="t-permalink"><a href="/w/index.php?title=Undefined_behavior&amp;oldid=959672567" title="Permanent link to this revision of this page">Permanent link</a></li><li id="t-info"><a href="/w/index.php?title=Undefined_behavior&amp;action=info" title="More information about this page">Page information</a></li><li id="t-cite"><a href="/w/index.php?title=Special:CiteThisPage&amp;page=Undefined_behavior&amp;id=959672567&amp;wpFormIdentifier=titleform" title="Information on how to cite this page">Cite this page</a></li><li id="t-wikibase"><a accesskey="g" href="https://www.wikidata.org/wiki/Special:EntityPage/Q1964707" title="Structured data on this page hosted by Wikidata [g]">Wikidata item</a></li></ul>
#  </div>
#  </nav>
#  <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#  <nav aria-labelledby="p-coll-print_export-label" class="mw-portlet mw-portlet-coll-print_export vector-menu vector-menu-portal portal" id="p-coll-print_export" role="navigation">
#  <h3 id="p-coll-print_export-label">
#  <span>Print/export</span>
#  </h3>
#  <div class="vector-menu-content">
#  <ul class="vector-menu-content-list"><li id="coll-download-as-rl"><a href="/w/index.php?title=Special:DownloadAsPdf&amp;page=Undefined_behavior&amp;action=show-download-screen" title="Download this page as a PDF file">Download as PDF</a></li><li id="t-print"><a accesskey="p" href="/w/index.php?title=Undefined_behavior&amp;printable=yes" title="Printable version of this page [p]">Printable version</a></li></ul>
#  </div>
#  </nav>
#  <!-- Please do not use role attribute as CSS selector, it is deprecated. -->
#  <nav aria-labelledby="p-lang-label" class="mw-portlet mw-portlet-lang vector-menu vector-menu-portal portal" id="p-lang" role="navigation">
#  <h3 id="p-lang-label">
#  <span>Languages</span>
#  </h3>
#  <div class="vector-menu-content">
#  <ul class="vector-menu-content-list"><li class="interlanguage-link interwiki-de"><a class="interlanguage-link-target" href="https://de.wikipedia.org/wiki/Undefiniertes_Verhalten" hreflang="de" lang="de" title="Undefiniertes Verhalten – German">Deutsch</a></li><li class="interlanguage-link interwiki-es"><a class="interlanguage-link-target" href="https://es.wikipedia.org/wiki/Comportamiento_indefinido" hreflang="es" lang="es" title="Comportamiento indefinido – Spanish">Español</a></li><li class="interlanguage-link interwiki-fa"><a class="interlanguage-link-target" href="https://fa.wikipedia.org/wiki/%D8%B1%D9%81%D8%AA%D8%A7%D8%B1_%D9%86%D8%A7%D9%85%D8%B4%D8%AE%D8%B5" hreflang="fa" lang="fa" title="رفتار نامشخص – Persian">فارسی</a></li><li class="interlanguage-link interwiki-no"><a class="interlanguage-link-target" href="https://no.wikipedia.org/wiki/Udefinert_oppf%C3%B8rsel" hreflang="nb" lang="nb" title="Udefinert oppførsel – Norwegian Bokmål">Norsk bokmål</a></li><li class="interlanguage-link interwiki-nn"><a class="interlanguage-link-target" href="https://nn.wikipedia.org/wiki/Udefinert_%C3%A5tferd" hreflang="nn" lang="nn" title="Udefinert åtferd – Norwegian Nynorsk">Norsk nynorsk</a></li><li class="interlanguage-link interwiki-pt"><a class="interlanguage-link-target" href="https://pt.wikipedia.org/wiki/Comportamento_indefinido" hreflang="pt" lang="pt" title="Comportamento indefinido – Portuguese">Português</a></li><li class="interlanguage-link interwiki-ru"><a class="interlanguage-link-target" href="https://ru.wikipedia.org/wiki/%D0%9D%D0%B5%D0%BE%D0%BF%D1%80%D0%B5%D0%B4%D0%B5%D0%BB%D1%91%D0%BD%D0%BD%D0%BE%D0%B5_%D0%BF%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D0%B5" hreflang="ru" lang="ru" title="Неопределённое поведение – Russian">Русский</a></li><li class="interlanguage-link interwiki-sr"><a class="interlanguage-link-target" href="https://sr.wikipedia.org/wiki/%D0%9D%D0%B5%D0%B4%D0%B5%D1%84%D0%B8%D0%BD%D0%B8%D1%81%D0%B0%D0%BD%D0%BE_%D0%BF%D0%BE%D0%BD%D0%B0%D1%88%D0%B0%D1%9A%D0%B5" hreflang="sr" lang="sr" title="Недефинисано понашање – Serbian">Српски / srpski</a></li><li class="interlanguage-link interwiki-uk"><a class="interlanguage-link-target" href="https://uk.wikipedia.org/wiki/%D0%9D%D0%B5%D0%B2%D0%B8%D0%B7%D0%BD%D0%B0%D1%87%D0%B5%D0%BD%D0%B0_%D0%BF%D0%BE%D0%B2%D0%B5%D0%B4%D1%96%D0%BD%D0%BA%D0%B0" hreflang="uk" lang="uk" title="Невизначена поведінка – Ukrainian">Українська</a></li><li class="interlanguage-link interwiki-zh"><a class="interlanguage-link-target" href="https://zh.wikipedia.org/wiki/%E6%9C%AA%E5%AE%9A%E4%B9%89%E8%A1%8C%E4%B8%BA" hreflang="zh" lang="zh" title="未定义行为 – Chinese">中文</a></li></ul>
#  <div class="after-portlet after-portlet-lang"><span class="wb-langlinks-edit wb-langlinks-link"><a class="wbc-editpage" href="https://www.wikidata.org/wiki/Special:EntityPage/Q1964707#sitelinks-wikipedia" title="Edit interlanguage links">Edit links</a></span></div>
#  </div>
#  </nav>
#  </div>
#  </div>
#  <footer class="mw-footer" id="footer" role="contentinfo">
#  <ul id="footer-info">
#  <li id="footer-info-lastmod"> This page was last edited on 30 May 2020, at 00:28<span class="anonymous-show"> (UTC)</span>.</li>
#  <li id="footer-info-copyright">Text is available under the <a href="//en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License" rel="license">Creative Commons Attribution-ShareAlike License</a><a href="//creativecommons.org/licenses/by-sa/3.0/" rel="license" style="display:none;"></a>;
#  additional terms may apply.  By using this site, you agree to the <a href="//foundation.wikimedia.org/wiki/Terms_of_Use">Terms of Use</a> and <a href="//foundation.wikimedia.org/wiki/Privacy_policy">Privacy Policy</a>. Wikipedia® is a registered trademark of the <a href="//www.wikimediafoundation.org/">Wikimedia Foundation, Inc.</a>, a non-profit organization.</li>
#  </ul>
#  <ul id="footer-places">
#  <li id="footer-places-privacy"><a class="extiw" href="https://foundation.wikimedia.org/wiki/Privacy_policy" title="wmf:Privacy policy">Privacy policy</a></li>
#  <li id="footer-places-about"><a href="/wiki/Wikipedia:About" title="Wikipedia:About">About Wikipedia</a></li>
#  <li id="footer-places-disclaimer"><a href="/wiki/Wikipedia:General_disclaimer" title="Wikipedia:General disclaimer">Disclaimers</a></li>
#  <li id="footer-places-contact"><a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us">Contact Wikipedia</a></li>
#  <li id="footer-places-mobileview"><a class="noprint stopMobileRedirectToggle" href="//en.m.wikipedia.org/w/index.php?title=Undefined_behavior&amp;mobileaction=toggle_view_mobile">Mobile view</a></li>
#  <li id="footer-places-developers"><a href="https://www.mediawiki.org/wiki/Special:MyLanguage/How_to_contribute">Developers</a></li>
#  <li id="footer-places-statslink"><a href="https://stats.wikimedia.org/#/en.wikipedia.org">Statistics</a></li>
#  <li id="footer-places-cookiestatement"><a href="https://foundation.wikimedia.org/wiki/Cookie_statement">Cookie statement</a></li>
#  </ul>
#  <ul class="noprint" id="footer-icons">
#  <li id="footer-copyrightico"><a href="https://wikimediafoundation.org/"><img alt="Wikimedia Foundation" height="31" loading="lazy" src="/static/images/footer/wikimedia-button.png" srcset="/static/images/footer/wikimedia-button-1.5x.png 1.5x, /static/images/footer/wikimedia-button-2x.png 2x" width="88"/></a></li>
#  <li id="footer-poweredbyico"><a href="https://www.mediawiki.org/"><img alt="Powered by MediaWiki" height="31" loading="lazy" src="/static/images/footer/poweredby_mediawiki_88x31.png" srcset="/static/images/footer/poweredby_mediawiki_132x47.png 1.5x, /static/images/footer/poweredby_mediawiki_176x62.png 2x" width="88"/></a></li>
#  </ul>
#  <div style="clear: both;"></div>
#  </footer>
#  <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgPageParseReport":{"limitreport":{"cputime":"0.344","walltime":"7.894","ppvisitednodes":{"value":1147,"limit":1000000},"postexpandincludesize":{"value":12658,"limit":2097152},"templateargumentsize":{"value":1467,"limit":2097152},"expansiondepth":{"value":23,"limit":40},"expensivefunctioncount":{"value":1,"limit":500},"unstrip-depth":{"value":1,"limit":20},"unstrip-size":{"value":33322,"limit":5000000},"entityaccesscount":{"value":0,"limit":400},"timingprofile":["100.00% 7848.542      1 -total","  2.15%  168.980      1 Template:Reflist","  1.47%  115.183      6 Template:Cite_web","  0.95%   74.278      1 Template:Citation_needed","  0.74%   58.094      1 Template:Fix","  0.55%   42.960      1 Template:ISBN","  0.46%   35.751      2 Template:Category_handler","  0.43%   33.428      1 Template:Distinguish","  0.39%   30.581      1 Template:Kilde_www","  0.21%   16.610      1 Template:Catalog_lookup_link"]},"scribunto":{"limitreport-timeusage":{"value":"0.123","limit":"10.000"},"limitreport-memusage":{"value":4904351,"limit":52428800}},"cachereport":{"origin":"mw1403","timestamp":"20201029221546","ttl":2592000,"transientcontent":false}}});});</script>
#  <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","name":"Undefined behavior","url":"https:\/\/en.wikipedia.org\/wiki\/Undefined_behavior","sameAs":"http:\/\/www.wikidata.org\/entity\/Q1964707","mainEntity":"http:\/\/www.wikidata.org\/entity\/Q1964707","author":{"@type":"Organization","name":"Contributors to Wikimedia projects"},"publisher":{"@type":"Organization","name":"Wikimedia Foundation, Inc.","logo":{"@type":"ImageObject","url":"https:\/\/www.wikimedia.org\/static\/images\/wmf-hor-googpub.png"}},"datePublished":"2004-03-09T21:33:24Z","dateModified":"2020-05-30T00:28:58Z","headline":"behavior of erroneous computer programs that the language standard permits to be unpredictable"}</script>
#  <script>(RLQ=window.RLQ||[]).push(function(){mw.config.set({"wgBackendResponseTime":132,"wgHostname":"mw1355"});});</script>
#  </body></html>,
#  'raw_text': 'In computer programming, undefined behavior (UB) is the result of executing a program whose behavior is prescribed to be unpredictable, in the language specification to which the computer code adheres. This is different from unspecified behavior, for which the language specification does not prescribe a result and implementation defined behavior that defers to the documentation of another component of the platform (such as the ABI or the translator documentation). In the C community, undefined behavior may be humorously referred to as "nasal demons", after a comp.std.c post that explained undefined behavior as allowing the compiler to do anything it chooses, even "to make demons fly out of your nose".[1] 1 Overview2 Benefits3 Risks4 Examples in C and C++5 See also6 References7 Further reading8 External linksSome programming languages allow a program to operate differently or even have a different control flow than the source code, as long as it exhibits the same user-visible side effects, if undefined behavior never happens during program execution. Undefined behavior is the name of a list of conditions that the program must not meet. In the early versions of C, undefined behavior\'s primary advantage was the production of performant compilers for a wide variety of machines: a specific construct could be mapped to a machine-specific feature, and the compiler did not have to generate additional code for the runtime to adapt the side effects to match semantics imposed by the language. The program source code was written with prior knowledge of the specific compiler and of the platforms that it would support. However, progressive standardization of the platforms has made this less of an advantage, especially in newer versions of C. Now, the cases for undefined behavior typically represent unambiguous bugs in the code, for example indexing an array outside of its bounds. By definition, the runtime can assume that undefined behavior never happens; therefore, some invalid conditions do not need to be checked against. For a compiler, this also means that various program transformations become valid, or their proofs of correctness are simplified; this allows for various kinds of premature optimization and micro-optimization, which lead to incorrect behavior if the program state meets any of such conditions. The compiler can also remove explicit checks that may have been in the source code, without notifying the programmer; for example, detecting undefined behavior by testing whether it happened is not guaranteed to work, by definition. This makes it hard or impossible to program a portable fail-safe option (non-portable solutions are possible for some constructs). Current compiler development usually evaluates and compares compiler performance with benchmarks designed around micro-optimizations, even on platforms that are mostly used on the general-purpose desktop and laptop market (such as amd64). Therefore, undefined behavior provides ample room for compiler performance improvement, as the source code for a specific source code statement is allowed to be mapped to anything at runtime. For C and C++, the compiler is allowed to give a compile-time diagnostic in these cases, but is not required to: the implementation will be considered correct whatever it does in such cases, analogous to don\'t-care terms in digital logic. It is the responsibility of the programmer to write code that never invokes undefined behavior, although compiler implementations are allowed to issue diagnostics when this happens. Compilers nowadays have flags that enable such diagnostics, for example, -fsanitize enables the "undefined behavior sanitizer" (UBSan) in gcc 4.9[2] and in clang. However, this flag is not the default and enabling it is a choice of who builds the code. Under some circumstances there can be specific restrictions on undefined behavior. For example, the instruction set specifications of a CPU might leave the behavior of some fo ...

# %%
#flatten nested structure in order to pickle; hence kwn
FINAL = []
for i in range(len(master)):
    for index in (range(len(master[i]))):
        item = {
            "kwn": i,
            "kw": master[i][index]["kw"],
            "link": master[i][index]["link"],
            "soup": str(master[i][index]["soup"]), #pickle cannot accept bs4 object, convert to string
            "text": master[i][index]["raw_text"]
        }
        FINAL.append(item)

# %%
#export site objects to file for heuristics selection phase
with open("mined_sites_0_30.txt", "wb") as fp:
    pickle.dump(FINAL, fp)
